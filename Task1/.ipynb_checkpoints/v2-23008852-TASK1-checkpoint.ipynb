# %% [markdown]
# <img src="https://pa-legg.github.io/images/uwe_banner.png">
#
# # UFCFFY-15-M Cyber Security Analytics 23-24
#
# ## Portfolio Assignment: Worksheet 1
# ## Investigate a web server application logs to identify malicious attack activity using Python data science libraries
# ---
#
# For this task, the company **"UWEtech"** have enlisted your support as a security data analyst. They suspect some kind of attack on their web server application, however they are unable to diagnose what has happened exactly, or which of their users have caused the attack. The company have provided you with their recent log data records. You will need to complete a series of tasks to examine the data further, and then expand your investigation to uncover any malicious activity.
#
# **Dataset**: You will be randomly issued a **unique dataset** based on your UWE username - **failure to use the dataset assigned to your username will result in a zero grade**. Please see the folder ***"Portfolio Assignment"*** under the Assignment tab on Blackboard for further detail related to the access and download of the necessary dataset.
#
# ### Assessment and Marking
# ---
# The completion of this worksheet is worth **20%** of your portfolio assignment for the UFCFFY-15-M Cyber Security Analytics (CSA) module. Each question states the possible marks available for a correct answer. Where a question is worth more than 1 mark, a partial solution to the question may warrant partial marks.
#
# ### Submission Documents
# ---
#
# Your submission for this task should include:
#
# - **1 Jupyter Notebook file (*.ipynb)**
#
# You should complete your work using the ipynb file provided (i.e., this document). Once you have completed your work, you should ensure that all code cells have been executed and then you should save your notebook. **Please note: Staff will NOT execute your notebook during marking. It is your responsibility to ensure that your saved notebook shows the code cell outputs as required.**
#
# The deadline for your portfolio submission is **THURSDAY 2ND MAY @ 14:00**. This assignment is eligible for the [48-hour late submission window](https://www.uwe.ac.uk/study/academic-information/personal-circumstances/late-submission-window), however module staff will not be able to assist with any queries after the deadline.
#
# Your portfolio submitted to Blackboard must contain 3 independent documents:
#
# - ***STUDENT_ID-TASK1.ipynb*** (your iPYNB with all cells executed)
# - ***STUDENT_ID-TASK2.ipynb*** (your iPYNB with all cells executed)
# - ***STUDENT_ID-TASK3.pdf*** (a PDF report of your research investigation)
#
# ### Contact
# ---
#
# Questions about this assignment should be directed to your module leader (Phil.Legg@uwe.ac.uk). You should use the [online Q&A form](https://forms.office.com/e/yxFJZDraRG) to ask questions related to this module and this assignment, as well as utilising the on-site teaching sessions.
#
# ---

# %% [markdown]
# # Student ID: 23008852
#
# - **By submitting this assignment to Blackboard as part of your portfolio, I declare that the submission is my own work.**
#
# ***

# %%
import matplotlib.pyplot as plt 
plt.style.use('ggplot')
import pandas as pd
import numpy as np
import networkx as nx
import seaborn as sns
pd.set_option('display.max_rows', 20)

# %% [markdown]
# In the cell below, you will need to change `data_file` to your own specific data filename. The example data file is purely to demonstrate some initial steps for your investigation and should not be used.

# %%
data_file = './y232-wang_2024jan_dataset.txt'

# %%
# Load in the data set as required
data = pd.read_csv(data_file, sep=r'\s+')
# original
# data = pd.read_csv(data_file, delim_whitespace=True)
temp_df = data[data.columns[:-1]]
temp_df.columns = data.columns[1:]
data = temp_df
data['datetime'] = pd.to_datetime(data['date'] + " " + data['time'])
data
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 0       2023-01-01  00:24:00  167.167.244.11       GET       gtbmiuyo.css
# 1       2023-01-01  00:24:00  167.167.244.11       GET         index.aspx
# 2       2023-01-01  00:24:28  167.167.244.11       GET         favico.ico
# 3       2023-01-01  00:24:28  167.167.244.11       GET       gcjnjeej.css
# 4       2023-01-01  00:24:28  167.167.244.11       GET           main.css
# ...            ...       ...             ...       ...                ...
# 350591  2023-01-30  23:55:45  167.167.244.11       GET  transactions.aspx
# 350592  2023-01-30  23:56:06  167.167.244.11       GET         footer.css
# 350593  2023-01-30  23:56:06  167.167.244.11       GET        ttcsdmrb.js
# 350594  2023-01-30  23:56:06  167.167.244.11       GET       phekuflm.css
# 350595  2023-01-30  23:56:06  167.167.244.11       GET        logout.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 0                 -     443           -  34.189.170.188
# 1                 -     443           -  34.189.170.188
# 2                 -     443           -  34.189.170.188
# 3                 -     443           -  34.189.170.188
# 4                 -     443           -  34.189.170.188
# ...             ...     ...         ...             ...
# 350591       page=1     443    um821644    45.94.33.238
# 350592            -     443           -    45.94.33.238
# 350593     v=746817     443           -    45.94.33.238
# 350594            -     443           -    45.94.33.238
# 350595            -     443           -    45.94.33.238
#
#                                            cs(User-Agent)  \
# 0       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 1       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 2       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 3       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 4       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 350591  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350592  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350593  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350594  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350595  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 0                                             -        200             0
# 1                                             -        200             0
# 2              https://uwetech.co.uk/index.aspx        200             0
# 3              https://uwetech.co.uk/index.aspx        404             0
# 4              https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 350591  https://uwetech.co.uk/transactions.aspx        200             0
# 350592  https://uwetech.co.uk/transactions.aspx        200             0
# 350593  https://uwetech.co.uk/transactions.aspx        200             0
# 350594  https://uwetech.co.uk/transactions.aspx        404             0
# 350595  https://uwetech.co.uk/transactions.aspx        301             0
#
#         sc-win32-status  time-taken            datetime
# 0                     0          27 2023-01-01 00:24:00
# 1                     0          22 2023-01-01 00:24:00
# 2                     0          23 2023-01-01 00:24:28
# 3                     0          23 2023-01-01 00:24:28
# 4                     0          29 2023-01-01 00:24:28
# ...                 ...         ...                 ...
# 350591                0          24 2023-01-30 23:55:45
# 350592                0          22 2023-01-30 23:56:06
# 350593                0          20 2023-01-30 23:56:06
# 350594                0          22 2023-01-30 23:56:06
# 350595                0          26 2023-01-30 23:56:06
#
# [350596 rows x 16 columns]

# %% [markdown]
# ### Question 1: Show how often each of the unique machines (defined by client IP address 'c-ip') have accessed this web server application? (1 Mark)
#
# *Hint: Think about how you would count the occurrence of all possible values within a Dataframe column.*

# %%
# Q1 ANSWER
# Count the unique client IP addresses and print the outputs in order
def factor_col(col):
    factor = pd.Categorical(col)
    return pd.Series(factor).value_counts(sort=False)

df = pd.DataFrame(data['c-ip'])

# count the numbers of each client IP address by following the original order in the array

f_cip = pd.DataFrame(factor_col(df['c-ip']))

# c-ips are sorted in a desending order
sort_f_cip = f_cip.sort_values('count', ascending=False)
sort_f_cip
# Out:
#                  count
# 198.169.194.238    332
# 89.43.49.3         280
# 135.244.31.76      272
# 194.245.32.53      221
# 94.177.126.101     155
# ...                ...
# 45.85.127.121       20
# 185.184.115.39      20
# 195.82.125.220      19
# 45.95.10.120        19
# 195.248.192.46      18
#
# [5048 rows x 1 columns]

# %% [markdown]
# ### Question 2: Show how often each of the possible unique URLs (defined by 'cs(Referer)') have been accessed within the dataset? (1 Mark)
#
# *Hint: Think about how you would count the occurrence of all possible values within a Dataframe column.*

# %%
# Q2 ANSWER
# Count the possible unique URLs 'cs(Referer)'
def factor_col(col):
    factor = pd.Categorical(col)
    return pd.Series(factor).value_counts(sort=False)
    
# Count the numbers of the possible unique URLs 'cs(Referer)'
# Including '-'
df = pd.DataFrame(data['cs(Referer)'])
cre_ct = factor_col(df['cs(Referer)'])

# Remove '-' URLs

rrt_df = data[data['cs(Referer)'] != "-"]

# Count the numbers of the possible unique URLs 'cs(Referer)'
# Without '-'
cre = rrt_df['cs(Referer)']
cre_ct_02 = pd.Series(cre).value_counts()
pd.DataFrame(cre_ct_02)
# Out:
#                                                count
# cs(Referer)
# https://uwetech.co.uk/transactions.aspx       117177
# https://uwetech.co.uk/index.aspx               90058
# https://uwetech.co.uk/login.aspx               66459
# https://uwetech.co.uk/account_status.aspx      31088
# https://uwetech.co.uk/transfer.aspx             8782
# https://uwetech.co.uk/changepassword.aspx       3127
# https://uwetech.co.uk/faq.aspx                  1844
# https://uwetech.co.uk/transfer_complete.aspx    1496
# https://uwetech.co.uk/change_avatar.aspx         610

# %% [markdown]
# ### Question 3: Show how often each client IP has accessed each URL? (1 Mark)
#
# *Hint: Think about how you would count the occurrence of all possible pairs of values within multiple Dataframe columns.*

# %%
# Q3 ANSWER
# all '-' in URLs are removed in rrt_df 
xtab = pd.crosstab(rrt_df['c-ip'], rrt_df['cs(Referer)'])
xtab
# Out:
# cs(Referer)      https://uwetech.co.uk/account_status.aspx  \
# c-ip
# 101.167.223.24                                           4
# 102.129.155.160                                          2
# 102.129.64.24                                            7
# 102.132.118.223                                          7
# 102.165.17.153                                           4
# ...                                                    ...
# 95.87.102.7                                              2
# 96.6.242.135                                             6
# 99.82.169.124                                            7
# 99.86.111.145                                            5
# 99.86.120.238                                            5
#
# cs(Referer)      https://uwetech.co.uk/change_avatar.aspx  \
# c-ip
# 101.167.223.24                                          0
# 102.129.155.160                                         0
# 102.129.64.24                                           0
# 102.132.118.223                                         0
# 102.165.17.153                                          0
# ...                                                   ...
# 95.87.102.7                                             0
# 96.6.242.135                                            0
# 99.82.169.124                                           0
# 99.86.111.145                                           0
# 99.86.120.238                                           0
#
# cs(Referer)      https://uwetech.co.uk/changepassword.aspx  \
# c-ip
# 101.167.223.24                                           0
# 102.129.155.160                                          7
# 102.129.64.24                                            0
# 102.132.118.223                                          0
# 102.165.17.153                                           0
# ...                                                    ...
# 95.87.102.7                                              0
# 96.6.242.135                                             6
# 99.82.169.124                                            0
# 99.86.111.145                                            0
# 99.86.120.238                                            0
#
# cs(Referer)      https://uwetech.co.uk/faq.aspx  \
# c-ip
# 101.167.223.24                                0
# 102.129.155.160                               0
# 102.129.64.24                                 0
# 102.132.118.223                               0
# 102.165.17.153                                0
# ...                                         ...
# 95.87.102.7                                   0
# 96.6.242.135                                  0
# 99.82.169.124                                 0
# 99.86.111.145                                 0
# 99.86.120.238                                 0
#
# cs(Referer)      https://uwetech.co.uk/index.aspx  \
# c-ip
# 101.167.223.24                                 14
# 102.129.155.160                                11
# 102.129.64.24                                  16
# 102.132.118.223                                19
# 102.165.17.153                                  7
# ...                                           ...
# 95.87.102.7                                     9
# 96.6.242.135                                   19
# 99.82.169.124                                  19
# 99.86.111.145                                  21
# 99.86.120.238                                  16
#
# cs(Referer)      https://uwetech.co.uk/login.aspx  \
# c-ip
# 101.167.223.24                                  9
# 102.129.155.160                                 7
# 102.129.64.24                                  18
# 102.132.118.223                                12
# 102.165.17.153                                  7
# ...                                           ...
# 95.87.102.7                                     7
# 96.6.242.135                                   11
# 99.82.169.124                                  14
# 99.86.111.145                                  11
# 99.86.120.238                                  14
#
# cs(Referer)      https://uwetech.co.uk/transactions.aspx  \
# c-ip
# 101.167.223.24                                        31
# 102.129.155.160                                        8
# 102.129.64.24                                         18
# 102.132.118.223                                       24
# 102.165.17.153                                         9
# ...                                                  ...
# 95.87.102.7                                           17
# 96.6.242.135                                          22
# 99.82.169.124                                         23
# 99.86.111.145                                         21
# 99.86.120.238                                         29
#
# cs(Referer)      https://uwetech.co.uk/transfer.aspx  \
# c-ip
# 101.167.223.24                                     4
# 102.129.155.160                                    0
# 102.129.64.24                                      0
# 102.132.118.223                                    0
# 102.165.17.153                                     0
# ...                                              ...
# 95.87.102.7                                        6
# 96.6.242.135                                       0
# 99.82.169.124                                      0
# 99.86.111.145                                      0
# 99.86.120.238                                      5
#
# cs(Referer)      https://uwetech.co.uk/transfer_complete.aspx
# c-ip
# 101.167.223.24                                              0
# 102.129.155.160                                             0
# 102.129.64.24                                               0
# 102.132.118.223                                             0
# 102.165.17.153                                              0
# ...                                                       ...
# 95.87.102.7                                                 0
# 96.6.242.135                                                0
# 99.82.169.124                                               0
# 99.86.111.145                                               0
# 99.86.120.238                                               0
#
# [5048 rows x 9 columns]

# %% [markdown]
# ### Question 4: Filter the data to show all rows where 'cs-uri-query' starts with the string 'v='. (1 Mark)

# %%
# Q4 ANSWER

# Extract all rows where 'cs-uri-query' starts with the string 'v='
df = pd.DataFrame(data)

df['cuq'] = df['cs-uri-query']
df['cuq'] = df['cuq'].str.contains('v=', regex=True)
df[df['cuq'] == True ]
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 7       2023-01-01  00:24:46  167.167.244.11       GET  template.css
# 21      2023-01-01  00:26:26  167.167.244.11       GET   cvppenru.js
# 24      2023-01-01  00:26:50  167.167.244.11       GET   aucmigtu.js
# 30      2023-01-01  00:27:25  167.167.244.11       GET   btnjzjas.js
# 32      2023-01-01  00:27:25  167.167.244.11       GET  template.css
# ...            ...       ...             ...       ...           ...
# 350551  2023-01-30  23:36:04  167.167.244.11       GET  template.css
# 350556  2023-01-30  23:36:30  167.167.244.11       GET   iapbjxvb.js
# 350559  2023-01-30  23:36:42  167.167.244.11       GET   gpqoymli.js
# 350573  2023-01-30  23:54:34  167.167.244.11       GET  template.css
# 350593  2023-01-30  23:56:06  167.167.244.11       GET   ttcsdmrb.js
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 7        v=vbdhwsnk     443           -  34.189.170.188
# 21         v=385746     443    dd915907  34.189.170.188
# 24         v=529178     443    dd915907  34.189.170.188
# 30         v=389361     443    dd915907  34.189.170.188
# 32       v=cdpginre     443    dd915907  34.189.170.188
# ...             ...     ...         ...             ...
# 350551   v=ninqvvzh     443    ec212315  212.221.91.206
# 350556     v=920035     443    ec212315  212.221.91.206
# 350559     v=813268     443    ec212315  212.221.91.206
# 350573   v=usxjtpda     443           -    45.94.33.238
# 350593     v=746817     443           -    45.94.33.238
#
#                                            cs(User-Agent)  \
# 7       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 21      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 24      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 30      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 32      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 350551  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350556  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350559  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350573  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350593  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 7                https://uwetech.co.uk/index.aspx        200             0
# 21        https://uwetech.co.uk/transactions.aspx        200             0
# 24        https://uwetech.co.uk/transactions.aspx        200             0
# 30        https://uwetech.co.uk/transactions.aspx        200             0
# 32        https://uwetech.co.uk/transactions.aspx        200             0
# ...                                           ...        ...           ...
# 350551  https://uwetech.co.uk/account_status.aspx        200             0
# 350556    https://uwetech.co.uk/transactions.aspx        200             0
# 350559    https://uwetech.co.uk/transactions.aspx        200             0
# 350573           https://uwetech.co.uk/index.aspx        200             0
# 350593    https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime   cuq
# 7                     0          21 2023-01-01 00:24:46  True
# 21                    0          23 2023-01-01 00:26:26  True
# 24                    0          30 2023-01-01 00:26:50  True
# 30                    0          26 2023-01-01 00:27:25  True
# 32                    0          24 2023-01-01 00:27:25  True
# ...                 ...         ...                 ...   ...
# 350551                0          23 2023-01-30 23:36:04  True
# 350556                0          29 2023-01-30 23:36:30  True
# 350559                0          23 2023-01-30 23:36:42  True
# 350573                0          23 2023-01-30 23:54:34  True
# 350593                0          20 2023-01-30 23:56:06  True
#
# [58202 rows x 17 columns]

# %% [markdown]
# ### Question 5: Filter the data to show all rows where 'cs(User-Agent)' contain the string 'Win64? (1 Mark)

# %%
# Q5 ANSWER
df = pd.DataFrame(data)
# Extract all rows where 'cs(User-Agent)' contain the string 'Win64'
df['cua'] = df['cs(User-Agent)']
df['cua_win64'] = df['cua'].str.contains('Win64', regex=True )
df[df['cua_win64'] == True ]
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 41      2023-01-01  01:50:00  167.167.244.11       GET         favico.ico
# 42      2023-01-01  01:50:00  167.167.244.11       GET         index.aspx
# 43      2023-01-01  01:50:05  167.167.244.11       GET         footer.css
# 44      2023-01-01  01:50:05  167.167.244.11       GET         index.aspx
# 45      2023-01-01  01:50:21  167.167.244.11       GET         footer.css
# ...            ...       ...             ...       ...                ...
# 350563  2023-01-30  23:37:02  167.167.244.11       GET       cpthgxry.css
# 350564  2023-01-30  23:37:02  167.167.244.11       GET  transactions.aspx
# 350565  2023-01-30  23:37:20  167.167.244.11       GET         favico.ico
# 350566  2023-01-30  23:37:20  167.167.244.11       GET           main.css
# 350567  2023-01-30  23:37:20  167.167.244.11       GET        logout.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 41                -     443           -     40.96.45.69
# 42                -     443           -     40.96.45.69
# 43                -     443           -     40.96.45.69
# 44                -     443           -     40.96.45.69
# 45                -     443           -     40.96.45.69
# ...             ...     ...         ...             ...
# 350563            -     443    ec212315  212.221.91.206
# 350564       page=5     443    ec212315  212.221.91.206
# 350565            -     443           -  212.221.91.206
# 350566            -     443           -  212.221.91.206
# 350567            -     443           -  212.221.91.206
#
#                                            cs(User-Agent)  \
# 41      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 42      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 43      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 44      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 45      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# ...                                                   ...
# 350563  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350564  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350565  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350566  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350567  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 41                                            -        200             0
# 42                                            -        200             0
# 43             https://uwetech.co.uk/index.aspx        200             0
# 44             https://uwetech.co.uk/index.aspx        200             0
# 45             https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 350563  https://uwetech.co.uk/transactions.aspx        404             0
# 350564  https://uwetech.co.uk/transactions.aspx        200             0
# 350565  https://uwetech.co.uk/transactions.aspx        200             0
# 350566  https://uwetech.co.uk/transactions.aspx        200             0
# 350567  https://uwetech.co.uk/transactions.aspx        301             0
#
#         sc-win32-status  time-taken            datetime  \
# 41                    0          27 2023-01-01 01:50:00
# 42                    0          21 2023-01-01 01:50:00
# 43                    0          20 2023-01-01 01:50:05
# 44                    0          26 2023-01-01 01:50:05
# 45                    0          24 2023-01-01 01:50:21
# ...                 ...         ...                 ...
# 350563                0          27 2023-01-30 23:37:02
# 350564                0          25 2023-01-30 23:37:02
# 350565                0          25 2023-01-30 23:37:20
# 350566                0          21 2023-01-30 23:37:20
# 350567                0          25 2023-01-30 23:37:20
#
#                                                       cua  cua_win64
# 41      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 42      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 43      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 44      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 45      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# ...                                                   ...        ...
# 350563  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 350564  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 350565  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 350566  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 350567  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
#
# [106705 rows x 18 columns]

# %% [markdown]
# ### Question 6: Filter the data to show all rows where 'sc-status' is equal to 404, before 07:00AM? (1 Mark)

# %%
# Q6 ANSWER
# Extract all rows where 'sc-status' is equal to 404, before 07:00AM
df = pd.DataFrame(data)
ss_df = df[(df['sc-status'] == 404) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00')) ]
ss_df
# Out:
# C:\Users\lesmo\AppData\Local\Temp\ipykernel_2720\3236956486.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ss_df = df[(df['sc-status'] == 404) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00')) ]
#               date      time            s-ip cs-method   cs-uri-stem  \
# 3       2023-01-01  00:24:28  167.167.244.11       GET  gcjnjeej.css
# 6       2023-01-01  00:24:46  167.167.244.11       GET  xbiklmrm.css
# 18      2023-01-01  00:25:57  167.167.244.11       GET  wwypwlwh.css
# 27      2023-01-01  00:27:20  167.167.244.11       GET  haewjbil.css
# 38      2023-01-01  00:28:05  167.167.244.11       GET  uqyxxljj.css
# ...            ...       ...             ...       ...           ...
# 339290  2023-01-30  06:41:00  167.167.244.11       GET  erketzjl.css
# 339302  2023-01-30  06:41:58  167.167.244.11       GET  ehozajkz.css
# 339313  2023-01-30  06:43:05  167.167.244.11       GET  hyydbllh.css
# 339315  2023-01-30  06:43:17  167.167.244.11       GET  pzdkusmj.css
# 339338  2023-01-30  06:46:57  167.167.244.11       GET  pzplakfk.css
#
#        cs-uri-query  s-port cs-username             c-ip  \
# 3                 -     443           -   34.189.170.188
# 6                 -     443           -   34.189.170.188
# 18                -     443    dd915907   34.189.170.188
# 27                -     443    dd915907   34.189.170.188
# 38                -     443    dd915907   34.189.170.188
# ...             ...     ...         ...              ...
# 339290            -     443           -  212.161.102.129
# 339302            -     443           -  212.161.102.129
# 339313            -     443    zh670520  212.161.102.129
# 339315            -     443    zh670520  212.161.102.129
# 339338            -     443    ww271710    212.211.33.51
#
#                                            cs(User-Agent)  \
# 3       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 6       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 18      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 27      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 38      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 339290  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339302  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339313  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339315  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339338  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 3                https://uwetech.co.uk/index.aspx        404             0
# 6                https://uwetech.co.uk/index.aspx        404             0
# 18      https://uwetech.co.uk/account_status.aspx        404             0
# 27        https://uwetech.co.uk/transactions.aspx        404             0
# 38        https://uwetech.co.uk/transactions.aspx        404             0
# ...                                           ...        ...           ...
# 339290                                          -        404             0
# 339302           https://uwetech.co.uk/index.aspx        404             0
# 339313    https://uwetech.co.uk/transactions.aspx        404             0
# 339315    https://uwetech.co.uk/transactions.aspx        404             0
# 339338           https://uwetech.co.uk/login.aspx        404             0
#
#         sc-win32-status  time-taken            datetime
# 3                     0          23 2023-01-01 00:24:28
# 6                     0          28 2023-01-01 00:24:46
# 18                    0          23 2023-01-01 00:25:57
# 27                    0          29 2023-01-01 00:27:20
# 38                    0          23 2023-01-01 00:28:05
# ...                 ...         ...                 ...
# 339290                0          24 2023-01-30 06:41:00
# 339302                0          25 2023-01-30 06:41:58
# 339313                0          29 2023-01-30 06:43:05
# 339315                0          26 2023-01-30 06:43:17
# 339338                0          22 2023-01-30 06:46:57
#
# [1786 rows x 16 columns]

# %% [markdown]
# ### Question 7: Plot a Bar Chart showing the number of entries for each value in 'sc-status'. (1 Mark)
#
# *Hint: Matplotlib and Pandas are closely linked - some pandas functions have matplotlib functions embedded. Read the documentation for more detail.*

# %%
# Q7 ANSWER

plt.figure(figsize=(8,7))
sns.countplot(x='sc-status',data=data, hue='sc-status', palette='magma')
plt.title('Count of sc-status')  # Add title
plt.xlabel('sc-status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Question 8: Plot a line chart that shows the number of records (Y-axis) vs each day within the dataset (X-axis). (1 Mark)

# %%
# Q8 ANSWER

df = pd.DataFrame(data)
# sort by date
da_ct = factor_col(df['date'])
da=da_ct.to_dict()
da
# Out:
# {'2023-01-01': 12301,
#  '2023-01-02': 11204,
#  '2023-01-03': 11219,
#  '2023-01-04': 11583,
#  '2023-01-05': 11833,
#  '2023-01-06': 10701,
#  '2023-01-07': 12620,
#  '2023-01-08': 12385,
#  '2023-01-09': 11276,
#  '2023-01-10': 12542,
#  '2023-01-11': 12293,
#  '2023-01-12': 10382,
#  '2023-01-13': 10703,
#  '2023-01-14': 12616,
#  '2023-01-15': 11229,
#  '2023-01-16': 11337,
#  '2023-01-17': 13060,
#  '2023-01-18': 12110,
#  '2023-01-19': 11862,
#  '2023-01-20': 11884,
#  '2023-01-21': 11670,
#  '2023-01-22': 11400,
#  '2023-01-23': 11981,
#  '2023-01-24': 11377,
#  '2023-01-25': 11022,
#  '2023-01-26': 11859,
#  '2023-01-27': 11323,
#  '2023-01-28': 11039,
#  '2023-01-29': 11832,
#  '2023-01-30': 11953}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert the dictionary 'da' into a DataFrame
dff = pd.DataFrame(list(da.items()), columns=['Date', 'Value'])

# Set the 'Date' column as datetime type
dff['Date'] = pd.to_datetime(dff['Date'])

# Create line plot using seaborn
plt.figure(figsize=(14, 6)) 
sns.lineplot(x='Date', y='Value', data=dff, marker='o')
plt.title('Each day within the dataset ')
plt.xlabel('Date')
plt.ylabel('Number of records')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# ### (Advanced) Question 9: Filter and Plot a Network graph using the NetworkX library based on the criteria below (4 Marks)
#
# * Filter the data to only the 20 most active IP addresses and plot this using a Network chart **(1 Mark)**.
# * (Advanced) Scale each client node within the chart based on the amount of activity **(3 Marks)**.

# %%
# Q9 ANSWER
# Count the numbers
def factor_col(col):
    factor = pd.Categorical(col)
    return pd.Series(factor).value_counts(sort=False)
    
# ----------------------------------------------------------------------------------------------------------
# Q9.1 Filter the data to only the 20 most active IP addresses and plot this using a Network chart (1 Mark).
# ----------------------------------------------------------------------------------------------------------

df = pd.DataFrame(data['c-ip'])

# count the numbers of each client IP address by following the original order in the array
f_cip = pd.DataFrame(factor_col(df['c-ip']))

s_cip = data['s-ip'].unique()
s_cip
# Out:
# array(['167.167.244.11'], dtype=object)

# %%
s_cip = {cip: 1 for cip in s_cip}
s_cip
# Out:
# {'167.167.244.11': 1}

# %%
# c-ips are sorted in a desending order
sort_f_cip = f_cip.sort_values('count', ascending=False)


# Top 20 Active IPs, sorted in descending order
net_ip = sort_f_cip[:20]
graph_dict = net_ip.to_dict()
node_data = graph_dict['count']
node_data
# Out:
# {'198.169.194.238': 332,
#  '89.43.49.3': 280,
#  '135.244.31.76': 272,
#  '194.245.32.53': 221,
#  '94.177.126.101': 155,
#  '95.215.11.248': 149,
#  '205.138.33.178': 145,
#  '80.76.62.181': 145,
#  '192.160.10.14': 144,
#  '129.36.232.219': 143,
#  '82.206.139.145': 142,
#  '62.190.21.164': 141,
#  '185.166.158.241': 140,
#  '84.233.192.94': 139,
#  '154.54.21.171': 139,
#  '193.19.156.141': 138,
#  '81.27.85.89': 138,
#  '165.225.81.217': 138,
#  '185.83.53.183': 137,
#  '185.170.176.36': 137}

# %%
import networkx as nx
import matplotlib.pyplot as plt


# Create a NetworkX graph
G = nx.Graph()

# Add nodes to the graph and set node sizes based on counts
for node, count in node_data.items():
    G.add_node(node, count=count)

# Add s_cip node(s)
for cip in s_cip:
    G.add_node(cip)

# Connect each node in node_data to s_cip node(s)
for node in node_data.keys():
    for cip in s_cip:
        G.add_edge(node, cip)

# Draw the network chart
nx.draw(G, with_labels=True, labels={node: f"{node}\nCount: {count}" for node, count in node_data.items()}, 
        node_color='skyblue', node_size=500, font_size=6, edge_color='gray')

plt.title("Network Chart with Connections to s_ip")
plt.show()

# %%
# Create a NetworkX graph
G = nx.Graph()

# Add nodes to the graph and set node sizes based on counts
for node, count in node_data.items():
    # Adjust the size based on count
    G.add_node(node, count=count, size=count * 10) 

# Add s_cip node(s)
for cip, size in s_cip.items():
    G.add_node(cip, size=size)

# Connect each node in node_data to s_cip node(s)
for node in node_data.keys():
    for cip in s_cip.keys():
        G.add_edge(node, cip)

# Draw the network chart
nx.draw(G, with_labels=True, labels={node: f"{node}\nCount: {node_data[node]}" if node in node_data else f"{node}\nCount: 0" for node in G.nodes()}, 
        node_color='coral', node_size=[G.nodes[node].get('size', 100) for node in G.nodes()], font_size=6, edge_color='gray')

plt.title("Scale Each Client Node Based On The Amount Of Activity")
plt.show()

# %% [markdown]
# ### Question 10:  Investigate the dataset further to uncover the suspicious activity (8 marks)
#
# This unguided question will be graded against the following criteria:
#
# - Identifying all suspicious activity within your dataset **(3 Marks)**
# - Analytical reasoning of investigating why this activity is suspicious **(3 Marks)**
# - Clarity and presentation **(2 Marks)**
#
# You should state all suspicious IP addresses that you have identified as part of your conclusion, and you should explain in clear written English how you have uncovered this information, based on how you have used Python code for data investigation. This should be clear and concise, and you only need to include code that helped you to solve the challenge.

# %% [markdown]
# # Identifying all suspicious activity within your dataset

# %%
# Q10 ANSWER

# Count the possible unique URLs 'cs(Referer)'
def factor_col(col):
    factor = pd.Categorical(col)
    return pd.Series(factor).value_counts(sort=False)
    

# Extract all rows where 'sc-status' is equal to 404, before 07:00AM
df = pd.DataFrame(data)
ss_df = df[(df['sc-status'] == 200) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00'))  & (df['date'] == '2023-01-15') ]
ssdf_ct = factor_col(ss_df['c-ip'])
top10_ssdf = ssdf_ct.sort_values(ascending=False)[:10]
test = top10_ssdf.to_dict()

ss_df[df['c-ip'] == '195.78.111.37']
ss_df
# Out:
# C:\Users\lesmo\AppData\Local\Temp\ipykernel_2720\4125950473.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ss_df = df[(df['sc-status'] == 200) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00'))  & (df['date'] == '2023-01-15') ]
# C:\Users\lesmo\AppData\Local\Temp\ipykernel_2720\4125950473.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ss_df[df['c-ip'] == '195.78.111.37']
#               date      time            s-ip cs-method        cs-uri-stem  \
# 163658  2023-01-15  01:25:00  167.167.244.11       GET           main.css
# 163659  2023-01-15  01:25:00  167.167.244.11       GET         index.aspx
# 163661  2023-01-15  01:25:05  167.167.244.11       GET         footer.css
# 163662  2023-01-15  01:25:05  167.167.244.11       GET         index.aspx
# 163663  2023-01-15  01:25:23  167.167.244.11       GET       oeplkroa.css
# ...            ...       ...             ...       ...                ...
# 164407  2023-01-15  06:58:10  167.167.244.11       GET         favico.ico
# 164408  2023-01-15  06:58:10  167.167.244.11       GET  transactions.aspx
# 164409  2023-01-15  06:58:28  167.167.244.11       GET         favico.ico
# 164410  2023-01-15  06:58:28  167.167.244.11       GET        jhxxytxu.js
# 164411  2023-01-15  06:58:28  167.167.244.11       GET  transactions.aspx
#
#        cs-uri-query  s-port cs-username             c-ip  \
# 163658            -     443           -    195.78.111.37
# 163659            -     443           -    195.78.111.37
# 163661            -     443           -    195.78.111.37
# 163662            -     443           -    195.78.111.37
# 163663            -     443           -    195.78.111.37
# ...             ...     ...         ...              ...
# 164407            -     443    jg139529  152.158.122.244
# 164408       page=2     443    jg139529  152.158.122.244
# 164409            -     443    jg139529  152.158.122.244
# 164410     v=765110     443    jg139529  152.158.122.244
# 164411       page=1     443    jg139529  152.158.122.244
#
#                                            cs(User-Agent)  \
# 163658  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 163659  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 163661  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 163662  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 163663  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# ...                                                   ...
# 164407  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 164408  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 164409  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 164410  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 164411  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 163658                                          -        200             0
# 163659                                          -        200             0
# 163661           https://uwetech.co.uk/index.aspx        200             0
# 163662           https://uwetech.co.uk/index.aspx        200             0
# 163663           https://uwetech.co.uk/index.aspx        200             0
# ...                                           ...        ...           ...
# 164407  https://uwetech.co.uk/account_status.aspx        200             0
# 164408  https://uwetech.co.uk/account_status.aspx        200             0
# 164409    https://uwetech.co.uk/transactions.aspx        200             0
# 164410    https://uwetech.co.uk/transactions.aspx        200             0
# 164411    https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 163658                0          29 2023-01-15 01:25:00
# 163659                0          27 2023-01-15 01:25:00
# 163661                0          30 2023-01-15 01:25:05
# 163662                0          30 2023-01-15 01:25:05
# 163663                0          20 2023-01-15 01:25:23
# ...                 ...         ...                 ...
# 164407                0          27 2023-01-15 06:58:10
# 164408                0          20 2023-01-15 06:58:10
# 164409                0          21 2023-01-15 06:58:28
# 164410                0          23 2023-01-15 06:58:28
# 164411                0          23 2023-01-15 06:58:28
#
# [631 rows x 16 columns]

# %%
data
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 0       2023-01-01  00:24:00  167.167.244.11       GET       gtbmiuyo.css
# 1       2023-01-01  00:24:00  167.167.244.11       GET         index.aspx
# 2       2023-01-01  00:24:28  167.167.244.11       GET         favico.ico
# 3       2023-01-01  00:24:28  167.167.244.11       GET       gcjnjeej.css
# 4       2023-01-01  00:24:28  167.167.244.11       GET           main.css
# ...            ...       ...             ...       ...                ...
# 350591  2023-01-30  23:55:45  167.167.244.11       GET  transactions.aspx
# 350592  2023-01-30  23:56:06  167.167.244.11       GET         footer.css
# 350593  2023-01-30  23:56:06  167.167.244.11       GET        ttcsdmrb.js
# 350594  2023-01-30  23:56:06  167.167.244.11       GET       phekuflm.css
# 350595  2023-01-30  23:56:06  167.167.244.11       GET        logout.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 0                 -     443           -  34.189.170.188
# 1                 -     443           -  34.189.170.188
# 2                 -     443           -  34.189.170.188
# 3                 -     443           -  34.189.170.188
# 4                 -     443           -  34.189.170.188
# ...             ...     ...         ...             ...
# 350591       page=1     443    um821644    45.94.33.238
# 350592            -     443           -    45.94.33.238
# 350593     v=746817     443           -    45.94.33.238
# 350594            -     443           -    45.94.33.238
# 350595            -     443           -    45.94.33.238
#
#                                            cs(User-Agent)  \
# 0       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 1       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 2       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 3       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 4       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 350591  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350592  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350593  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350594  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350595  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 0                                             -        200             0
# 1                                             -        200             0
# 2              https://uwetech.co.uk/index.aspx        200             0
# 3              https://uwetech.co.uk/index.aspx        404             0
# 4              https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 350591  https://uwetech.co.uk/transactions.aspx        200             0
# 350592  https://uwetech.co.uk/transactions.aspx        200             0
# 350593  https://uwetech.co.uk/transactions.aspx        200             0
# 350594  https://uwetech.co.uk/transactions.aspx        404             0
# 350595  https://uwetech.co.uk/transactions.aspx        301             0
#
#         sc-win32-status  time-taken            datetime
# 0                     0          27 2023-01-01 00:24:00
# 1                     0          22 2023-01-01 00:24:00
# 2                     0          23 2023-01-01 00:24:28
# 3                     0          23 2023-01-01 00:24:28
# 4                     0          29 2023-01-01 00:24:28
# ...                 ...         ...                 ...
# 350591                0          24 2023-01-30 23:55:45
# 350592                0          22 2023-01-30 23:56:06
# 350593                0          20 2023-01-30 23:56:06
# 350594                0          22 2023-01-30 23:56:06
# 350595                0          26 2023-01-30 23:56:06
#
# [350596 rows x 16 columns]

# %%
data['s-port'].value_counts()
# Out:
# s-port
# 443    350596
# Name: count, dtype: int64

# %%
data['s-ip'].value_counts()
# Out:
# s-ip
# 167.167.244.11    350596
# Name: count, dtype: int64

# %%
data['c-ip'].value_counts()
# Out:
# c-ip
# 198.169.194.238    332
# 89.43.49.3         280
# 135.244.31.76      272
# 194.245.32.53      221
# 94.177.126.101     155
#                   ...
# 185.184.115.39      20
# 213.155.153.2       20
# 45.95.10.120        19
# 195.82.125.220      19
# 195.248.192.46      18
# Name: count, Length: 5048, dtype: int64

# %%
# f_cip = pd.DataFrame(factor_col(df['c-ip']))
f_cip
# Out:
#                  count
# 101.167.223.24      69
# 102.129.155.160     37
# 102.129.64.24       65
# 102.132.118.223     69
# 102.165.17.153      31
# ...                ...
# 95.87.102.7         44
# 96.6.242.135        71
# 99.82.169.124       68
# 99.86.111.145       65
# 99.86.120.238       74
#
# [5048 rows x 1 columns]

# %%
data['cs-username'].value_counts()
# Out:
# cs-username
# -           135714
# ik640020       117
# lb893196       111
# rl825368       110
# na648390       106
#              ...
# om315513         9
# sb219128         8
# hp204865         8
# nu294936         8
# lt292647         8
# Name: count, Length: 5048, dtype: int64

# %%
data['cs(Referer)'].value_counts()
# Out:
# cs(Referer)
# https://uwetech.co.uk/transactions.aspx         117177
# https://uwetech.co.uk/index.aspx                 90058
# https://uwetech.co.uk/login.aspx                 66459
# https://uwetech.co.uk/account_status.aspx        31088
# -                                                29955
# https://uwetech.co.uk/transfer.aspx               8782
# https://uwetech.co.uk/changepassword.aspx         3127
# https://uwetech.co.uk/faq.aspx                    1844
# https://uwetech.co.uk/transfer_complete.aspx      1496
# https://uwetech.co.uk/change_avatar.aspx           610
# Name: count, dtype: int64

# %%
data['cs-uri-query'].value_counts()
# Out:
# cs-uri-query
# -                   245282
# page=2               18369
# page=1               10004
# page=3                6684
# page=4                4979
#                      ...
# v=107026                 1
# v=filyfzeu               1
# v=236042                 1
# accountid=369127         1
# v=746817                 1
# Name: count, Length: 59172, dtype: int64

# %%
data['time-taken'].value_counts()
# Out:
# time-taken
# 21    32162
# 20    32139
# 28    32054
# 29    32041
# 27    31957
# 25    31900
# 24    31800
# 30    31778
# 26    31663
# 23    31604
# 22    31498
# Name: count, dtype: int64

# %%
data['cs-method'].value_counts()
# Out:
# cs-method
# GET     335854
# POST     14742
# Name: count, dtype: int64

# %% [markdown]
# # Investigate Suspicious IPs
# Investigate activities during 00:00 A.M. - 07:00 A.M.

# %%
df = pd.DataFrame(data)
ss_df = df[(df['sc-status'] == 404) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00')) ]
ss_df
# Out:
# C:\Users\lesmo\AppData\Local\Temp\ipykernel_2720\1840786903.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ss_df = df[(df['sc-status'] == 404) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00')) ]
#               date      time            s-ip cs-method   cs-uri-stem  \
# 3       2023-01-01  00:24:28  167.167.244.11       GET  gcjnjeej.css
# 6       2023-01-01  00:24:46  167.167.244.11       GET  xbiklmrm.css
# 18      2023-01-01  00:25:57  167.167.244.11       GET  wwypwlwh.css
# 27      2023-01-01  00:27:20  167.167.244.11       GET  haewjbil.css
# 38      2023-01-01  00:28:05  167.167.244.11       GET  uqyxxljj.css
# ...            ...       ...             ...       ...           ...
# 339290  2023-01-30  06:41:00  167.167.244.11       GET  erketzjl.css
# 339302  2023-01-30  06:41:58  167.167.244.11       GET  ehozajkz.css
# 339313  2023-01-30  06:43:05  167.167.244.11       GET  hyydbllh.css
# 339315  2023-01-30  06:43:17  167.167.244.11       GET  pzdkusmj.css
# 339338  2023-01-30  06:46:57  167.167.244.11       GET  pzplakfk.css
#
#        cs-uri-query  s-port cs-username             c-ip  \
# 3                 -     443           -   34.189.170.188
# 6                 -     443           -   34.189.170.188
# 18                -     443    dd915907   34.189.170.188
# 27                -     443    dd915907   34.189.170.188
# 38                -     443    dd915907   34.189.170.188
# ...             ...     ...         ...              ...
# 339290            -     443           -  212.161.102.129
# 339302            -     443           -  212.161.102.129
# 339313            -     443    zh670520  212.161.102.129
# 339315            -     443    zh670520  212.161.102.129
# 339338            -     443    ww271710    212.211.33.51
#
#                                            cs(User-Agent)  \
# 3       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 6       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 18      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 27      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 38      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 339290  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339302  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339313  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339315  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339338  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 3                https://uwetech.co.uk/index.aspx        404             0
# 6                https://uwetech.co.uk/index.aspx        404             0
# 18      https://uwetech.co.uk/account_status.aspx        404             0
# 27        https://uwetech.co.uk/transactions.aspx        404             0
# 38        https://uwetech.co.uk/transactions.aspx        404             0
# ...                                           ...        ...           ...
# 339290                                          -        404             0
# 339302           https://uwetech.co.uk/index.aspx        404             0
# 339313    https://uwetech.co.uk/transactions.aspx        404             0
# 339315    https://uwetech.co.uk/transactions.aspx        404             0
# 339338           https://uwetech.co.uk/login.aspx        404             0
#
#         sc-win32-status  time-taken            datetime
# 3                     0          23 2023-01-01 00:24:28
# 6                     0          28 2023-01-01 00:24:46
# 18                    0          23 2023-01-01 00:25:57
# 27                    0          29 2023-01-01 00:27:20
# 38                    0          23 2023-01-01 00:28:05
# ...                 ...         ...                 ...
# 339290                0          24 2023-01-30 06:41:00
# 339302                0          25 2023-01-30 06:41:58
# 339313                0          29 2023-01-30 06:43:05
# 339315                0          26 2023-01-30 06:43:17
# 339338                0          22 2023-01-30 06:46:57
#
# [1786 rows x 16 columns]

# %%
df = pd.DataFrame(data)
ab_df = df[((df['sc-status'] == 200) | (df['sc-status'] == 404)) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00')) ]
ab_df
# Out:
# C:\Users\lesmo\AppData\Local\Temp\ipykernel_2720\2724796288.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ab_df = df[((df['sc-status'] == 200) | (df['sc-status'] == 404)) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00')) ]
#               date      time            s-ip cs-method        cs-uri-stem  \
# 0       2023-01-01  00:24:00  167.167.244.11       GET       gtbmiuyo.css
# 1       2023-01-01  00:24:00  167.167.244.11       GET         index.aspx
# 2       2023-01-01  00:24:28  167.167.244.11       GET         favico.ico
# 3       2023-01-01  00:24:28  167.167.244.11       GET       gcjnjeej.css
# 4       2023-01-01  00:24:28  167.167.244.11       GET           main.css
# ...            ...       ...             ...       ...                ...
# 339344  2023-01-30  06:47:57  167.167.244.11       GET       template.css
# 339345  2023-01-30  06:47:57  167.167.244.11       GET       template.css
# 339346  2023-01-30  06:47:57  167.167.244.11       GET  transactions.aspx
# 339347  2023-01-30  06:48:08  167.167.244.11       GET         footer.css
# 339348  2023-01-30  06:48:08  167.167.244.11       GET  transactions.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 0                 -     443           -  34.189.170.188
# 1                 -     443           -  34.189.170.188
# 2                 -     443           -  34.189.170.188
# 3                 -     443           -  34.189.170.188
# 4                 -     443           -  34.189.170.188
# ...             ...     ...         ...             ...
# 339344   v=dcbqzhkr     443    ww271710   212.211.33.51
# 339345   v=hgmvuyph     443    ww271710   212.211.33.51
# 339346       page=1     443    ww271710   212.211.33.51
# 339347            -     443    ww271710   212.211.33.51
# 339348       page=2     443    ww271710   212.211.33.51
#
#                                            cs(User-Agent)  \
# 0       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 1       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 2       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 3       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 4       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 339344  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 339345  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 339346  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 339347  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 339348  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 0                                             -        200             0
# 1                                             -        200             0
# 2              https://uwetech.co.uk/index.aspx        200             0
# 3              https://uwetech.co.uk/index.aspx        404             0
# 4              https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 339344  https://uwetech.co.uk/transactions.aspx        200             0
# 339345  https://uwetech.co.uk/transactions.aspx        200             0
# 339346  https://uwetech.co.uk/transactions.aspx        200             0
# 339347  https://uwetech.co.uk/transactions.aspx        200             0
# 339348  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 0                     0          27 2023-01-01 00:24:00
# 1                     0          22 2023-01-01 00:24:00
# 2                     0          23 2023-01-01 00:24:28
# 3                     0          23 2023-01-01 00:24:28
# 4                     0          29 2023-01-01 00:24:28
# ...                 ...         ...                 ...
# 339344                0          22 2023-01-30 06:47:57
# 339345                0          24 2023-01-30 06:47:57
# 339346                0          27 2023-01-30 06:47:57
# 339347                0          21 2023-01-30 06:48:08
# 339348                0          27 2023-01-30 06:48:08
#
# [20063 rows x 16 columns]

# %%
ab_df['c-ip'].value_counts()
# Out:
# c-ip
# 57.246.1.216       90
# 195.149.186.132    83
# 212.119.7.15       78
# 195.78.111.37      76
# 185.22.170.240     71
#                    ..
# 185.64.226.69      10
# 31.40.248.10        9
# 38.87.46.5          8
# 158.175.114.177     7
# 23.79.225.45        4
# Name: count, Length: 592, dtype: int64

# %%
ss_df['sc-status'].value_counts()
# Out:
# sc-status
# 404    1786
# Name: count, dtype: int64

# %%
m7 = ss_df[ss_df['c-ip'] == '193.29.12.211']
m7
# Out:
#              date      time            s-ip cs-method   cs-uri-stem  \
# 12303  2023-01-02  00:20:00  167.167.244.11       GET  rpghvntv.css
# 12305  2023-01-02  00:20:04  167.167.244.11       GET  gjgpigcj.css
# 12314  2023-01-02  00:20:40  167.167.244.11       GET  nmgfxutu.css
# 12319  2023-01-02  00:21:20  167.167.244.11       GET  alqjcifa.css
# 12322  2023-01-02  00:21:28  167.167.244.11       GET  ichdsoyz.css
# 12329  2023-01-02  00:21:48  167.167.244.11       GET  wozgxdlj.css
# 12332  2023-01-02  00:21:55  167.167.244.11       GET  uqgqsqbd.css
# 12335  2023-01-02  00:22:17  167.167.244.11       GET  nnfqytxe.css
# 12337  2023-01-02  00:22:17  167.167.244.11       GET  hkbdgggx.css
#
#       cs-uri-query  s-port cs-username           c-ip  \
# 12303            -     443           -  193.29.12.211
# 12305            -     443           -  193.29.12.211
# 12314            -     443    si918477  193.29.12.211
# 12319            -     443    si918477  193.29.12.211
# 12322            -     443    si918477  193.29.12.211
# 12329            -     443    si918477  193.29.12.211
# 12332            -     443    si918477  193.29.12.211
# 12335            -     443    si918477  193.29.12.211
# 12337            -     443    si918477  193.29.12.211
#
#                                           cs(User-Agent)  \
# 12303  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_3+like+M...
# 12305  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_3+like+M...
# 12314  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_3+like+M...
# 12319  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_3+like+M...
# 12322  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_3+like+M...
# 12329  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_3+like+M...
# 12332  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_3+like+M...
# 12335  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_3+like+M...
# 12337  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 23845             -     443    ot146362  104.132.116.98
# 23847             -     443    ot146362  104.132.116.98
# 23849             -     443    ot146362  104.132.116.98
# 23850             -     443    ot146362  104.132.116.98
# 23854             -     443    ot146362  104.132.116.98
# 211916            -     443           -  104.132.116.98
# 211924            -     443    ot146362  104.132.116.98
# 211937            -     443           -  104.132.116.98
#
#                                            cs(User-Agent)  \
# 23845   Mozilla/4.0+(compatible;+MSIE+7.0;+Windows+NT+...
# 23847   Mozilla/4.0+(compatible;+MSIE+7.0;+Windows+NT+...
# 23849   Mozilla/4.0+(compatible;+MSIE+7.0;+Windows+NT+...
# 23850   Mozilla/4.0+(compatible;+MSIE+7.0;+Windows+NT+...
# 23854   Mozilla/4.0+(compatible;+MSIE+7.0;+Windows+NT+...
# 211916  Mozilla/4.0+(compatible;+MSIE+7.0;+Windows+NT+...
# 211924  Mozilla/4.0+(compatible;+MSIE+7.0;+Windows+NT+...
# 211937  Mozilla/4.0+(compatible;+MSIE+7.0;+Windows+NT+...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 23845            https://uwetech.co.uk/login.aspx        404             0
# 23847            https://uwetech.co.uk/login.aspx        404             0
# 23849            https://uwetech.co.uk/login.aspx        404             0
# 23850            https://uwetech.co.uk/login.aspx        404             0
# 23854   https://uwetech.co.uk/account_status.aspx        404             0
# 211916           https://uwetech.co.uk/index.aspx        404             0
# 211924           https://uwetech.co.uk/login.aspx        404             0
# 211937    https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime
# 23845                 0          23 2023-01-03 06:11:29
# 23847                 0          25 2023-01-03 06:11:29
# 23849                 0          29 2023-01-03 06:11:52
# 23850                 0          21 2023-01-03 06:11:52
# 23854                 0          22 2023-01-03 06:12:17
# 211916                0          27 2023-01-19 06:10:13
# 211924                0          30 2023-01-19 06:11:16
# 211937                0          28 2023-01-19 06:12:25

# %%
m15 = ss_df[ss_df['c-ip'] == '195.149.186.132']
m15
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 174987  2023-01-16  01:59:00  167.167.244.11       GET  rzmzufll.css
# 175000  2023-01-16  02:00:00  167.167.244.11       GET  nckejnec.css
# 175005  2023-01-16  02:00:08  167.167.244.11       GET  twhlsfom.css
# 175009  2023-01-16  02:00:26  167.167.244.11       GET  wdfgzmiw.css
# 175031  2023-01-16  02:02:03  167.167.244.11       GET  vxzrrial.css
# 304950  2023-01-27  05:54:49  167.167.244.11       GET  rdvkoqgj.css
# 304958  2023-01-27  05:55:37  167.167.244.11       GET  lckgvfzp.css
# 304969  2023-01-27  05:57:00  167.167.244.11       GET  glzczsmv.css
#
#        cs-uri-query  s-port cs-username             c-ip  \
# 174987            -     443           -  195.149.186.132
# 175000            -     443    kt180524  195.149.186.132
# 175005            -     443    kt180524  195.149.186.132
# 175009            -     443    kt180524  195.149.186.132
# 175031            -     443    kt180524  195.149.186.132
# 304950            -     443           -  195.149.186.132
# 304958            -     443    kt180524  195.149.186.132
# 304969            -     443    kt180524  195.149.186.132
#
#                                            cs(User-Agent)  \
# 174987  Mozilla/5.0+(Windows+NT+6.1;+WOW64;+Trident/7....
# 175000  Mozilla/5.0+(Windows+NT+6.1;+WOW64;+Trident/7....
# 175005  Mozilla/5.0+(Windows+NT+6.1;+WOW64;+Trident/7....
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 163699  2023-01-15  01:40:12  167.167.244.11       GET  zajykokx.css
# 163701  2023-01-15  01:40:12  167.167.244.11       GET  vzfgtyxe.css
# 163706  2023-01-15  01:40:32  167.167.244.11       GET  lxenlfib.css
# 163718  2023-01-15  01:41:06  167.167.244.11       GET  swegauje.css
# 163723  2023-01-15  01:41:56  167.167.244.11       GET  otizqqhi.css
# 163729  2023-01-15  01:42:31  167.167.244.11       GET  svygbvxu.css
# 163730  2023-01-15  01:42:31  167.167.244.11       GET  lphuvbju.css
#
#        cs-uri-query  s-port cs-username           c-ip  \
# 163699            -     443           -  85.205.61.166
# 163701            -     443           -  85.205.61.166
# 163706            -     443           -  85.205.61.166
# 163718            -     443    cl182664  85.205.61.166
# 163723            -     443    cl182664  85.205.61.166
# 163729            -     443    cl182664  85.205.61.166
# 163730            -     443    cl182664  85.205.61.166
#
#                                            cs(User-Agent)  \
# 163699  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 163701  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 163706  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 163718  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 163723  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 163729  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 163730  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 163699           https://uwetech.co.uk/index.aspx        404             0
# 163701           https://uwetech.co.uk/index.aspx        404             0
# 163706           https://uwetech.co.uk/index.aspx        404             0
# 163718  https://uwetech.co.uk/account_status.aspx        404             0
# 163723    https://uwetech.co.uk/transactions.aspx        404             0
# 163729    https://uwetech.co.uk/transactions.aspx        404             0
# 163730    https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime
# 163699                0          21 2023-01-15 01:40:12
# 163701                0          20 2023-01-15 01:40:12
# 163706                0          28 2023-01-15 01:40:32
# 163718                0          29 2023-01-15 01:41:06
# 163723                0          30 2023-01-15 01:41:56
# 163729                0          28 2023-01-15 01:42:31
# 163730                0          26 2023-01-15 01:42:31

# %%
# Investigate Windows devices
df = pd.DataFrame(data)
# Extract all rows where 'cs(User-Agent)' contain the string 'Win64'
aa = ss_df['cs(User-Agent)'].str.contains('Win64', regex=True)
aa.value_counts()
# Out:
# cs(User-Agent)
# False    1334
# True      452
# Name: count, dtype: int64

# %%
# Q6 ANSWER
# Extract all rows where 'sc-status' is equal to 404, before 07:00AM
df = pd.DataFrame(data)
a_df = df[(df['sc-status'] == 200) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00')) ]
a_df
# Out:
# C:\Users\lesmo\AppData\Local\Temp\ipykernel_2720\1590567849.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   a_df = df[(df['sc-status'] == 200) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00')) ]
#               date      time            s-ip cs-method        cs-uri-stem  \
# 0       2023-01-01  00:24:00  167.167.244.11       GET       gtbmiuyo.css
# 1       2023-01-01  00:24:00  167.167.244.11       GET         index.aspx
# 2       2023-01-01  00:24:28  167.167.244.11       GET         favico.ico
# 4       2023-01-01  00:24:28  167.167.244.11       GET           main.css
# 5       2023-01-01  00:24:28  167.167.244.11       GET         index.aspx
# ...            ...       ...             ...       ...                ...
# 339344  2023-01-30  06:47:57  167.167.244.11       GET       template.css
# 339345  2023-01-30  06:47:57  167.167.244.11       GET       template.css
# 339346  2023-01-30  06:47:57  167.167.244.11       GET  transactions.aspx
# 339347  2023-01-30  06:48:08  167.167.244.11       GET         footer.css
# 339348  2023-01-30  06:48:08  167.167.244.11       GET  transactions.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 0                 -     443           -  34.189.170.188
# 1                 -     443           -  34.189.170.188
# 2                 -     443           -  34.189.170.188
# 4                 -     443           -  34.189.170.188
# 5                 -     443           -  34.189.170.188
# ...             ...     ...         ...             ...
# 339344   v=dcbqzhkr     443    ww271710   212.211.33.51
# 339345   v=hgmvuyph     443    ww271710   212.211.33.51
# 339346       page=1     443    ww271710   212.211.33.51
# 339347            -     443    ww271710   212.211.33.51
# 339348       page=2     443    ww271710   212.211.33.51
#
#                                            cs(User-Agent)  \
# 0       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 1       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 2       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 4       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 5       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 339344  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 339345  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 339346  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 339347  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 339348  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 0                                             -        200             0
# 1                                             -        200             0
# 2              https://uwetech.co.uk/index.aspx        200             0
# 4              https://uwetech.co.uk/index.aspx        200             0
# 5              https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 339344  https://uwetech.co.uk/transactions.aspx        200             0
# 339345  https://uwetech.co.uk/transactions.aspx        200             0
# 339346  https://uwetech.co.uk/transactions.aspx        200             0
# 339347  https://uwetech.co.uk/transactions.aspx        200             0
# 339348  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 0                     0          27 2023-01-01 00:24:00
# 1                     0          22 2023-01-01 00:24:00
# 2                     0          23 2023-01-01 00:24:28
# 4                     0          29 2023-01-01 00:24:28
# 5                     0          25 2023-01-01 00:24:28
# ...                 ...         ...                 ...
# 339344                0          22 2023-01-30 06:47:57
# 339345                0          24 2023-01-30 06:47:57
# 339346                0          27 2023-01-30 06:47:57
# 339347                0          21 2023-01-30 06:48:08
# 339348                0          27 2023-01-30 06:48:08
#
# [18277 rows x 16 columns]

# %%
cc=a_df['c-ip'].value_counts().to_dict()
c_f_20 = dict(list(c.items())[:20])
c_f_20
# Out:
# {'195.78.111.37': 11,
#  '185.22.170.240': 10,
#  '185.250.96.229': 10,
#  '185.250.11.106': 9,
#  '195.183.191.59': 9,
#  '51.254.152.69': 9,
#  '193.29.12.211': 9,
#  '195.212.229.22': 8,
#  '2.22.140.181': 8,
#  '149.6.147.39': 8,
#  '23.79.247.3': 8,
#  '194.42.125.20': 8,
#  '81.93.233.99': 8,
#  '104.132.116.98': 8,
#  '195.149.186.132': 8,
#  '195.145.147.164': 7,
#  '213.86.21.240': 7,
#  '57.246.1.216': 7,
#  '93.115.155.87': 7,
#  '85.205.61.166': 7}

# %%
# ------------------------------------------------------------------------------------------------------ 
# Identifying all suspicious activity within your dataset (3 Marks)
# ------------------------------------------------------------------------------------------------------



# ------------------------------------------------------------------------------------------------------ 
# Analytical reasoning of investigating why this activity is suspicious (3 Marks)
# ------------------------------------------------------------------------------------------------------


# ------------------------------------------------------------------------------------------------------ 
# Clarity and presentation (2 Marks)
# ------------------------------------------------------------------------------------------------------
