# %% [markdown]
# <img src="https://pa-legg.github.io/images/uwe_banner.png">
#
# # UFCFFY-15-M Cyber Security Analytics 23-24
#
# ## Portfolio Assignment: Worksheet 1
# ## Investigate a web server application logs to identify malicious attack activity using Python data science libraries
# ---
#
# For this task, the company **"UWEtech"** have enlisted your support as a security data analyst. They suspect some kind of attack on their web server application, however they are unable to diagnose what has happened exactly, or which of their users have caused the attack. The company have provided you with their recent log data records. You will need to complete a series of tasks to examine the data further, and then expand your investigation to uncover any malicious activity.
#
# **Dataset**: You will be randomly issued a **unique dataset** based on your UWE username - **failure to use the dataset assigned to your username will result in a zero grade**. Please see the folder ***"Portfolio Assignment"*** under the Assignment tab on Blackboard for further detail related to the access and download of the necessary dataset.
#
# ### Assessment and Marking
# ---
# The completion of this worksheet is worth **20%** of your portfolio assignment for the UFCFFY-15-M Cyber Security Analytics (CSA) module. Each question states the possible marks available for a correct answer. Where a question is worth more than 1 mark, a partial solution to the question may warrant partial marks.
#
# ### Submission Documents
# ---
#
# Your submission for this task should include:
#
# - **1 Jupyter Notebook file (*.ipynb)**
#
# You should complete your work using the ipynb file provided (i.e., this document). Once you have completed your work, you should ensure that all code cells have been executed and then you should save your notebook. **Please note: Staff will NOT execute your notebook during marking. It is your responsibility to ensure that your saved notebook shows the code cell outputs as required.**
#
# The deadline for your portfolio submission is **THURSDAY 2ND MAY @ 14:00**. This assignment is eligible for the [48-hour late submission window](https://www.uwe.ac.uk/study/academic-information/personal-circumstances/late-submission-window), however module staff will not be able to assist with any queries after the deadline.
#
# Your portfolio submitted to Blackboard must contain 3 independent documents:
#
# - ***STUDENT_ID-TASK1.ipynb*** (your iPYNB with all cells executed)
# - ***STUDENT_ID-TASK2.ipynb*** (your iPYNB with all cells executed)
# - ***STUDENT_ID-TASK3.pdf*** (a PDF report of your research investigation)
#
# ### Contact
# ---
#
# Questions about this assignment should be directed to your module leader (Phil.Legg@uwe.ac.uk). You should use the [online Q&A form](https://forms.office.com/e/yxFJZDraRG) to ask questions related to this module and this assignment, as well as utilising the on-site teaching sessions.
#
# ---

# %% [markdown]
# # Student ID: 23008852
#
# - **By submitting this assignment to Blackboard as part of your portfolio, I declare that the submission is my own work.**
#
# ***

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd
import numpy as np
import networkx as nx
import seaborn as sns
pd.set_option('display.max_rows', 20)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# In the cell below, you will need to change `data_file` to your own specific data filename. The example data file is purely to demonstrate some initial steps for your investigation and should not be used.

# %%
data_file = './y232-wang_2024jan_dataset.txt'

# %%
# Load in the data set as required
data = pd.read_csv(data_file, sep=r'\s+')
# original
# data = pd.read_csv(data_file, delim_whitespace=True)
temp_df = data[data.columns[:-1]]
temp_df.columns = data.columns[1:]
data = temp_df
data['datetime'] = pd.to_datetime(data['date'] + " " + data['time'])
data
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 0       2023-01-01  00:24:00  167.167.244.11       GET       gtbmiuyo.css
# 1       2023-01-01  00:24:00  167.167.244.11       GET         index.aspx
# 2       2023-01-01  00:24:28  167.167.244.11       GET         favico.ico
# 3       2023-01-01  00:24:28  167.167.244.11       GET       gcjnjeej.css
# 4       2023-01-01  00:24:28  167.167.244.11       GET           main.css
# ...            ...       ...             ...       ...                ...
# 350591  2023-01-30  23:55:45  167.167.244.11       GET  transactions.aspx
# 350592  2023-01-30  23:56:06  167.167.244.11       GET         footer.css
# 350593  2023-01-30  23:56:06  167.167.244.11       GET        ttcsdmrb.js
# 350594  2023-01-30  23:56:06  167.167.244.11       GET       phekuflm.css
# 350595  2023-01-30  23:56:06  167.167.244.11       GET        logout.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 0                 -     443           -  34.189.170.188
# 1                 -     443           -  34.189.170.188
# 2                 -     443           -  34.189.170.188
# 3                 -     443           -  34.189.170.188
# 4                 -     443           -  34.189.170.188
# ...             ...     ...         ...             ...
# 350591       page=1     443    um821644    45.94.33.238
# 350592            -     443           -    45.94.33.238
# 350593     v=746817     443           -    45.94.33.238
# 350594            -     443           -    45.94.33.238
# 350595            -     443           -    45.94.33.238
#
#                                            cs(User-Agent)  \
# 0       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 1       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 2       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 3       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 4       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 350591  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350592  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350593  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350594  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350595  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 0                                             -        200             0
# 1                                             -        200             0
# 2              https://uwetech.co.uk/index.aspx        200             0
# 3              https://uwetech.co.uk/index.aspx        404             0
# 4              https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 350591  https://uwetech.co.uk/transactions.aspx        200             0
# 350592  https://uwetech.co.uk/transactions.aspx        200             0
# 350593  https://uwetech.co.uk/transactions.aspx        200             0
# 350594  https://uwetech.co.uk/transactions.aspx        404             0
# 350595  https://uwetech.co.uk/transactions.aspx        301             0
#
#         sc-win32-status  time-taken            datetime
# 0                     0          27 2023-01-01 00:24:00
# 1                     0          22 2023-01-01 00:24:00
# 2                     0          23 2023-01-01 00:24:28
# 3                     0          23 2023-01-01 00:24:28
# 4                     0          29 2023-01-01 00:24:28
# ...                 ...         ...                 ...
# 350591                0          24 2023-01-30 23:55:45
# 350592                0          22 2023-01-30 23:56:06
# 350593                0          20 2023-01-30 23:56:06
# 350594                0          22 2023-01-30 23:56:06
# 350595                0          26 2023-01-30 23:56:06
#
# [350596 rows x 16 columns]

# %% [markdown]
# ### Question 1: Show how often each of the unique machines (defined by client IP address 'c-ip') have accessed this web server application? (1 Mark)
#
# *Hint: Think about how you would count the occurrence of all possible values within a Dataframe column.*

# %%
# Q1 ANSWER
# Count the unique client IP addresses and print the outputs in order
def factor_col(col):
    factor = pd.Categorical(col)
    return pd.Series(factor).value_counts(sort=False)

df = pd.DataFrame(data['c-ip'])

# count the numbers of each client IP address by following the original order in the array

f_cip = pd.DataFrame(factor_col(df['c-ip']))

# c-ips are sorted in a desending order
sort_f_cip = f_cip.sort_values('count', ascending=False)
sort_f_cip
# Out:
#                  count
# 198.169.194.238    332
# 89.43.49.3         280
# 135.244.31.76      272
# 194.245.32.53      221
# 94.177.126.101     155
# ...                ...
# 45.85.127.121       20
# 185.184.115.39      20
# 195.82.125.220      19
# 45.95.10.120        19
# 195.248.192.46      18
#
# [5048 rows x 1 columns]

# %% [markdown]
# ### Question 2: Show how often each of the possible unique URLs (defined by 'cs(Referer)') have been accessed within the dataset? (1 Mark)
#
# *Hint: Think about how you would count the occurrence of all possible values within a Dataframe column.*

# %%
# Q2 ANSWER
# Count the possible unique URLs 'cs(Referer)'
def factor_col(col):
    factor = pd.Categorical(col)
    return pd.Series(factor).value_counts(sort=False)

# Count the numbers of the possible unique URLs 'cs(Referer)'
# Including '-'
df = pd.DataFrame(data['cs(Referer)'])
cre_ct = factor_col(df['cs(Referer)'])

# Remove '-' URLs

rrt_df = data[data['cs(Referer)'] != "-"]

# Count the numbers of the possible unique URLs 'cs(Referer)'
# Without '-'
cre = rrt_df['cs(Referer)']
cre_ct_02 = pd.Series(cre).value_counts()
pd.DataFrame(cre_ct_02)
# Out:
#                                                count
# cs(Referer)
# https://uwetech.co.uk/transactions.aspx       117177
# https://uwetech.co.uk/index.aspx               90058
# https://uwetech.co.uk/login.aspx               66459
# https://uwetech.co.uk/account_status.aspx      31088
# https://uwetech.co.uk/transfer.aspx             8782
# https://uwetech.co.uk/changepassword.aspx       3127
# https://uwetech.co.uk/faq.aspx                  1844
# https://uwetech.co.uk/transfer_complete.aspx    1496
# https://uwetech.co.uk/change_avatar.aspx         610

# %% [markdown]
# ### Question 3: Show how often each client IP has accessed each URL? (1 Mark)
#
# *Hint: Think about how you would count the occurrence of all possible pairs of values within multiple Dataframe columns.*

# %%
# Q3 ANSWER
# all '-' in URLs are removed in rrt_df
xtab = pd.crosstab(rrt_df['c-ip'], rrt_df['cs(Referer)'])
xtab
# Out:
# cs(Referer)      https://uwetech.co.uk/account_status.aspx  \
# c-ip
# 101.167.223.24                                           4
# 102.129.155.160                                          2
# 102.129.64.24                                            7
# 102.132.118.223                                          7
# 102.165.17.153                                           4
# ...                                                    ...
# 95.87.102.7                                              2
# 96.6.242.135                                             6
# 99.82.169.124                                            7
# 99.86.111.145                                            5
# 99.86.120.238                                            5
#
# cs(Referer)      https://uwetech.co.uk/change_avatar.aspx  \
# c-ip
# 101.167.223.24                                          0
# 102.129.155.160                                         0
# 102.129.64.24                                           0
# 102.132.118.223                                         0
# 102.165.17.153                                          0
# ...                                                   ...
# 95.87.102.7                                             0
# 96.6.242.135                                            0
# 99.82.169.124                                           0
# 99.86.111.145                                           0
# 99.86.120.238                                           0
#
# cs(Referer)      https://uwetech.co.uk/changepassword.aspx  \
# c-ip
# 101.167.223.24                                           0
# 102.129.155.160                                          7
# 102.129.64.24                                            0
# 102.132.118.223                                          0
# 102.165.17.153                                           0
# ...                                                    ...
# 95.87.102.7                                              0
# 96.6.242.135                                             6
# 99.82.169.124                                            0
# 99.86.111.145                                            0
# 99.86.120.238                                            0
#
# cs(Referer)      https://uwetech.co.uk/faq.aspx  \
# c-ip
# 101.167.223.24                                0
# 102.129.155.160                               0
# 102.129.64.24                                 0
# 102.132.118.223                               0
# 102.165.17.153                                0
# ...                                         ...
# 95.87.102.7                                   0
# 96.6.242.135                                  0
# 99.82.169.124                                 0
# 99.86.111.145                                 0
# 99.86.120.238                                 0
#
# cs(Referer)      https://uwetech.co.uk/index.aspx  \
# c-ip
# 101.167.223.24                                 14
# 102.129.155.160                                11
# 102.129.64.24                                  16
# 102.132.118.223                                19
# 102.165.17.153                                  7
# ...                                           ...
# 95.87.102.7                                     9
# 96.6.242.135                                   19
# 99.82.169.124                                  19
# 99.86.111.145                                  21
# 99.86.120.238                                  16
#
# cs(Referer)      https://uwetech.co.uk/login.aspx  \
# c-ip
# 101.167.223.24                                  9
# 102.129.155.160                                 7
# 102.129.64.24                                  18
# 102.132.118.223                                12
# 102.165.17.153                                  7
# ...                                           ...
# 95.87.102.7                                     7
# 96.6.242.135                                   11
# 99.82.169.124                                  14
# 99.86.111.145                                  11
# 99.86.120.238                                  14
#
# cs(Referer)      https://uwetech.co.uk/transactions.aspx  \
# c-ip
# 101.167.223.24                                        31
# 102.129.155.160                                        8
# 102.129.64.24                                         18
# 102.132.118.223                                       24
# 102.165.17.153                                         9
# ...                                                  ...
# 95.87.102.7                                           17
# 96.6.242.135                                          22
# 99.82.169.124                                         23
# 99.86.111.145                                         21
# 99.86.120.238                                         29
#
# cs(Referer)      https://uwetech.co.uk/transfer.aspx  \
# c-ip
# 101.167.223.24                                     4
# 102.129.155.160                                    0
# 102.129.64.24                                      0
# 102.132.118.223                                    0
# 102.165.17.153                                     0
# ...                                              ...
# 95.87.102.7                                        6
# 96.6.242.135                                       0
# 99.82.169.124                                      0
# 99.86.111.145                                      0
# 99.86.120.238                                      5
#
# cs(Referer)      https://uwetech.co.uk/transfer_complete.aspx
# c-ip
# 101.167.223.24                                              0
# 102.129.155.160                                             0
# 102.129.64.24                                               0
# 102.132.118.223                                             0
# 102.165.17.153                                              0
# ...                                                       ...
# 95.87.102.7                                                 0
# 96.6.242.135                                                0
# 99.82.169.124                                               0
# 99.86.111.145                                               0
# 99.86.120.238                                               0
#
# [5048 rows x 9 columns]

# %% [markdown]
# ### Question 4: Filter the data to show all rows where 'cs-uri-query' starts with the string 'v='. (1 Mark)

# %%
# Q4 ANSWER

# Extract all rows where 'cs-uri-query' starts with the string 'v='
df = pd.DataFrame(data)

df['cuq'] = df['cs-uri-query']
df['cuq'] = df['cuq'].str.contains('v=', regex=True)
df[df['cuq'] == True ]
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 7       2023-01-01  00:24:46  167.167.244.11       GET  template.css
# 21      2023-01-01  00:26:26  167.167.244.11       GET   cvppenru.js
# 24      2023-01-01  00:26:50  167.167.244.11       GET   aucmigtu.js
# 30      2023-01-01  00:27:25  167.167.244.11       GET   btnjzjas.js
# 32      2023-01-01  00:27:25  167.167.244.11       GET  template.css
# ...            ...       ...             ...       ...           ...
# 350551  2023-01-30  23:36:04  167.167.244.11       GET  template.css
# 350556  2023-01-30  23:36:30  167.167.244.11       GET   iapbjxvb.js
# 350559  2023-01-30  23:36:42  167.167.244.11       GET   gpqoymli.js
# 350573  2023-01-30  23:54:34  167.167.244.11       GET  template.css
# 350593  2023-01-30  23:56:06  167.167.244.11       GET   ttcsdmrb.js
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 7        v=vbdhwsnk     443           -  34.189.170.188
# 21         v=385746     443    dd915907  34.189.170.188
# 24         v=529178     443    dd915907  34.189.170.188
# 30         v=389361     443    dd915907  34.189.170.188
# 32       v=cdpginre     443    dd915907  34.189.170.188
# ...             ...     ...         ...             ...
# 350551   v=ninqvvzh     443    ec212315  212.221.91.206
# 350556     v=920035     443    ec212315  212.221.91.206
# 350559     v=813268     443    ec212315  212.221.91.206
# 350573   v=usxjtpda     443           -    45.94.33.238
# 350593     v=746817     443           -    45.94.33.238
#
#                                            cs(User-Agent)  \
# 7       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 21      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 24      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 30      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 32      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 350551  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350556  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350559  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350573  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350593  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 7                https://uwetech.co.uk/index.aspx        200             0
# 21        https://uwetech.co.uk/transactions.aspx        200             0
# 24        https://uwetech.co.uk/transactions.aspx        200             0
# 30        https://uwetech.co.uk/transactions.aspx        200             0
# 32        https://uwetech.co.uk/transactions.aspx        200             0
# ...                                           ...        ...           ...
# 350551  https://uwetech.co.uk/account_status.aspx        200             0
# 350556    https://uwetech.co.uk/transactions.aspx        200             0
# 350559    https://uwetech.co.uk/transactions.aspx        200             0
# 350573           https://uwetech.co.uk/index.aspx        200             0
# 350593    https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime   cuq
# 7                     0          21 2023-01-01 00:24:46  True
# 21                    0          23 2023-01-01 00:26:26  True
# 24                    0          30 2023-01-01 00:26:50  True
# 30                    0          26 2023-01-01 00:27:25  True
# 32                    0          24 2023-01-01 00:27:25  True
# ...                 ...         ...                 ...   ...
# 350551                0          23 2023-01-30 23:36:04  True
# 350556                0          29 2023-01-30 23:36:30  True
# 350559                0          23 2023-01-30 23:36:42  True
# 350573                0          23 2023-01-30 23:54:34  True
# 350593                0          20 2023-01-30 23:56:06  True
#
# [58202 rows x 17 columns]

# %% [markdown]
# ### Question 5: Filter the data to show all rows where 'cs(User-Agent)' contain the string 'Win64? (1 Mark)

# %%
# Q5 ANSWER
df = pd.DataFrame(data)
# Extract all rows where 'cs(User-Agent)' contain the string 'Win64'
df['cua'] = df['cs(User-Agent)']
df['cua_win64'] = df['cua'].str.contains('Win64', regex=True )
df[df['cua_win64'] == True ]
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 41      2023-01-01  01:50:00  167.167.244.11       GET         favico.ico
# 42      2023-01-01  01:50:00  167.167.244.11       GET         index.aspx
# 43      2023-01-01  01:50:05  167.167.244.11       GET         footer.css
# 44      2023-01-01  01:50:05  167.167.244.11       GET         index.aspx
# 45      2023-01-01  01:50:21  167.167.244.11       GET         footer.css
# ...            ...       ...             ...       ...                ...
# 350563  2023-01-30  23:37:02  167.167.244.11       GET       cpthgxry.css
# 350564  2023-01-30  23:37:02  167.167.244.11       GET  transactions.aspx
# 350565  2023-01-30  23:37:20  167.167.244.11       GET         favico.ico
# 350566  2023-01-30  23:37:20  167.167.244.11       GET           main.css
# 350567  2023-01-30  23:37:20  167.167.244.11       GET        logout.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 41                -     443           -     40.96.45.69
# 42                -     443           -     40.96.45.69
# 43                -     443           -     40.96.45.69
# 44                -     443           -     40.96.45.69
# 45                -     443           -     40.96.45.69
# ...             ...     ...         ...             ...
# 350563            -     443    ec212315  212.221.91.206
# 350564       page=5     443    ec212315  212.221.91.206
# 350565            -     443           -  212.221.91.206
# 350566            -     443           -  212.221.91.206
# 350567            -     443           -  212.221.91.206
#
#                                            cs(User-Agent)  \
# 41      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 42      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 43      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 44      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 45      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# ...                                                   ...
# 350563  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350564  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350565  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350566  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 350567  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 41                                            -        200             0
# 42                                            -        200             0
# 43             https://uwetech.co.uk/index.aspx        200             0
# 44             https://uwetech.co.uk/index.aspx        200             0
# 45             https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 350563  https://uwetech.co.uk/transactions.aspx        404             0
# 350564  https://uwetech.co.uk/transactions.aspx        200             0
# 350565  https://uwetech.co.uk/transactions.aspx        200             0
# 350566  https://uwetech.co.uk/transactions.aspx        200             0
# 350567  https://uwetech.co.uk/transactions.aspx        301             0
#
#         sc-win32-status  time-taken            datetime  \
# 41                    0          27 2023-01-01 01:50:00
# 42                    0          21 2023-01-01 01:50:00
# 43                    0          20 2023-01-01 01:50:05
# 44                    0          26 2023-01-01 01:50:05
# 45                    0          24 2023-01-01 01:50:21
# ...                 ...         ...                 ...
# 350563                0          27 2023-01-30 23:37:02
# 350564                0          25 2023-01-30 23:37:02
# 350565                0          25 2023-01-30 23:37:20
# 350566                0          21 2023-01-30 23:37:20
# 350567                0          25 2023-01-30 23:37:20
#
#                                                       cua  cua_win64
# 41      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 42      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 43      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 44      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 45      Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# ...                                                   ...        ...
# 350563  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 350564  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 350565  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 350566  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
# 350567  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...       True
#
# [106705 rows x 18 columns]

# %% [markdown]
# ### Question 6: Filter the data to show all rows where 'sc-status' is equal to 404, before 07:00AM? (1 Mark)

# %%
# Q6 ANSWER
# Extract all rows where 'sc-status' is equal to 404, before 07:00AM
df = pd.DataFrame(data)
ss_df = df[(df['sc-status'] == 404) & (pd.to_datetime(df['time']) < pd.to_datetime('07:00:00')) ]
ss_df
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 3       2023-01-01  00:24:28  167.167.244.11       GET  gcjnjeej.css
# 6       2023-01-01  00:24:46  167.167.244.11       GET  xbiklmrm.css
# 18      2023-01-01  00:25:57  167.167.244.11       GET  wwypwlwh.css
# 27      2023-01-01  00:27:20  167.167.244.11       GET  haewjbil.css
# 38      2023-01-01  00:28:05  167.167.244.11       GET  uqyxxljj.css
# ...            ...       ...             ...       ...           ...
# 339290  2023-01-30  06:41:00  167.167.244.11       GET  erketzjl.css
# 339302  2023-01-30  06:41:58  167.167.244.11       GET  ehozajkz.css
# 339313  2023-01-30  06:43:05  167.167.244.11       GET  hyydbllh.css
# 339315  2023-01-30  06:43:17  167.167.244.11       GET  pzdkusmj.css
# 339338  2023-01-30  06:46:57  167.167.244.11       GET  pzplakfk.css
#
#        cs-uri-query  s-port cs-username             c-ip  \
# 3                 -     443           -   34.189.170.188
# 6                 -     443           -   34.189.170.188
# 18                -     443    dd915907   34.189.170.188
# 27                -     443    dd915907   34.189.170.188
# 38                -     443    dd915907   34.189.170.188
# ...             ...     ...         ...              ...
# 339290            -     443           -  212.161.102.129
# 339302            -     443           -  212.161.102.129
# 339313            -     443    zh670520  212.161.102.129
# 339315            -     443    zh670520  212.161.102.129
# 339338            -     443    ww271710    212.211.33.51
#
#                                            cs(User-Agent)  \
# 3       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 6       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 18      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 27      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 38      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 339290  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339302  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339313  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339315  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+14_1+like+M...
# 339338  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 3                https://uwetech.co.uk/index.aspx        404             0
# 6                https://uwetech.co.uk/index.aspx        404             0
# 18      https://uwetech.co.uk/account_status.aspx        404             0
# 27        https://uwetech.co.uk/transactions.aspx        404             0
# 38        https://uwetech.co.uk/transactions.aspx        404             0
# ...                                           ...        ...           ...
# 339290                                          -        404             0
# 339302           https://uwetech.co.uk/index.aspx        404             0
# 339313    https://uwetech.co.uk/transactions.aspx        404             0
# 339315    https://uwetech.co.uk/transactions.aspx        404             0
# 339338           https://uwetech.co.uk/login.aspx        404             0
#
#         sc-win32-status  time-taken            datetime
# 3                     0          23 2023-01-01 00:24:28
# 6                     0          28 2023-01-01 00:24:46
# 18                    0          23 2023-01-01 00:25:57
# 27                    0          29 2023-01-01 00:27:20
# 38                    0          23 2023-01-01 00:28:05
# ...                 ...         ...                 ...
# 339290                0          24 2023-01-30 06:41:00
# 339302                0          25 2023-01-30 06:41:58
# 339313                0          29 2023-01-30 06:43:05
# 339315                0          26 2023-01-30 06:43:17
# 339338                0          22 2023-01-30 06:46:57
#
# [1786 rows x 16 columns]

# %% [markdown]
# ### Question 7: Plot a Bar Chart showing the number of entries for each value in 'sc-status'. (1 Mark)
#
# *Hint: Matplotlib and Pandas are closely linked - some pandas functions have matplotlib functions embedded. Read the documentation for more detail.*

# %%
# Q7 ANSWER

plt.figure(figsize=(8,7))
sns.countplot(x='sc-status',data=data, hue='sc-status', palette='magma')
plt.title('Count of sc-status')  # Add title
plt.xlabel('sc-status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Question 8: Plot a line chart that shows the number of records (Y-axis) vs each day within the dataset (X-axis). (1 Mark)

# %%
df = pd.DataFrame(data)
# sort by date
da_ct = factor_col(df['date'])
da=da_ct.to_dict()
da
# Out:
# {'2023-01-01': 12301,
#  '2023-01-02': 11204,
#  '2023-01-03': 11219,
#  '2023-01-04': 11583,
#  '2023-01-05': 11833,
#  '2023-01-06': 10701,
#  '2023-01-07': 12620,
#  '2023-01-08': 12385,
#  '2023-01-09': 11276,
#  '2023-01-10': 12542,
#  '2023-01-11': 12293,
#  '2023-01-12': 10382,
#  '2023-01-13': 10703,
#  '2023-01-14': 12616,
#  '2023-01-15': 11229,
#  '2023-01-16': 11337,
#  '2023-01-17': 13060,
#  '2023-01-18': 12110,
#  '2023-01-19': 11862,
#  '2023-01-20': 11884,
#  '2023-01-21': 11670,
#  '2023-01-22': 11400,
#  '2023-01-23': 11981,
#  '2023-01-24': 11377,
#  '2023-01-25': 11022,
#  '2023-01-26': 11859,
#  '2023-01-27': 11323,
#  '2023-01-28': 11039,
#  '2023-01-29': 11832,
#  '2023-01-30': 11953}

# %%
# Q8 ANSWER

# Convert the dictionary 'da' into a DataFrame
dff = pd.DataFrame(list(da.items()), columns=['Date', 'Value'])

# Set the 'Date' column as datetime type
dff['Date'] = pd.to_datetime(dff['Date'])

# Create line plot using seaborn
plt.figure(figsize=(14, 6))
sns.lineplot(x='Date', y='Value', data=dff, marker='*', markersize=15)
plt.title('Each day within the dataset ')
plt.xlabel('Date')
plt.ylabel('Number of records')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# ### (Advanced) Question 9: Filter and Plot a Network graph using the NetworkX library based on the criteria below (4 Marks)
#
# * Filter the data to only the 20 most active IP addresses and plot this using a Network chart **(1 Mark)**.
# * (Advanced) Scale each client node within the chart based on the amount of activity **(3 Marks)**.

# %%
# Q9 ANSWER
# Count the numbers
def factor_col(col):
    factor = pd.Categorical(col)
    return pd.Series(factor).value_counts(sort=False)

# ----------------------------------------------------------------------------------------------------------
# Q9.1 Filter the data to only the 20 most active IP addresses and plot this using a Network chart (1 Mark).
# ----------------------------------------------------------------------------------------------------------

df = pd.DataFrame(data['c-ip'])

# count the numbers of each client IP address by following the original order in the array
f_cip = pd.DataFrame(factor_col(df['c-ip']))

s_cip = data['s-ip'].unique()
s_cip
# Out:
# array(['167.167.244.11'], dtype=object)

# %%
s_cip = {cip: 1 for cip in s_cip}
s_cip
# Out:
# {'167.167.244.11': 1}

# %%
# c-ips are sorted in a desending order
sort_f_cip = f_cip.sort_values('count', ascending=False)


# Top 20 Active IPs, sorted in descending order
net_ip = sort_f_cip[:20]
graph_dict = net_ip.to_dict()
node_data = graph_dict['count']
node_data
# Out:
# {'198.169.194.238': 332,
#  '89.43.49.3': 280,
#  '135.244.31.76': 272,
#  '194.245.32.53': 221,
#  '94.177.126.101': 155,
#  '95.215.11.248': 149,
#  '205.138.33.178': 145,
#  '80.76.62.181': 145,
#  '192.160.10.14': 144,
#  '129.36.232.219': 143,
#  '82.206.139.145': 142,
#  '62.190.21.164': 141,
#  '185.166.158.241': 140,
#  '84.233.192.94': 139,
#  '154.54.21.171': 139,
#  '193.19.156.141': 138,
#  '81.27.85.89': 138,
#  '165.225.81.217': 138,
#  '185.83.53.183': 137,
#  '185.170.176.36': 137}

# %%
import networkx as nx
import matplotlib.pyplot as plt


# Create a NetworkX graph
G = nx.Graph()

# Add nodes to the graph and set node sizes based on counts
for node, count in node_data.items():
    G.add_node(node, count=count)

# Add s_cip node(s)
for cip in s_cip:
    G.add_node(cip)

# Connect each node in node_data to s_cip node(s)
for node in node_data.keys():
    for cip in s_cip:
        G.add_edge(node, cip)

# Draw the network chart
nx.draw(G, with_labels=True, labels={node: f"{node}\nCount: {count}" for node, count in node_data.items()},
        node_color='skyblue', node_size=500, font_size=6, edge_color='gray')

plt.title("Network Chart with Connections to s_ip")
plt.show()

# %%
# Create a NetworkX graph
G = nx.Graph()

# Add nodes to the graph and set node sizes based on counts
for node, count in node_data.items():
    # Adjust the size based on count
    G.add_node(node, count=count, size=count * 10)

# Add s_cip node(s)
for cip, size in s_cip.items():
    G.add_node(cip, size=size)

# Connect each node in node_data to s_cip node(s)
for node in node_data.keys():
    for cip in s_cip.keys():
        G.add_edge(node, cip)

# Draw the network chart
nx.draw(G, with_labels=True, labels={node: f"{node}\nCount: {node_data[node]}" if node in node_data else f"{node}\nCount: 0" for node in G.nodes()},
        node_color='coral', node_size=[G.nodes[node].get('size', 100) for node in G.nodes()], font_size=6, edge_color='gray')

plt.title("Scale Each Client Node Based On The Amount Of Activity")
plt.show()

# %% [markdown]
# ### Question 10:  Investigate the dataset further to uncover the suspicious activity (8 marks)
#
# This unguided question will be graded against the following criteria:
#
# - Identifying all suspicious activity within your dataset **(3 Marks)**
# - Analytical reasoning of investigating why this activity is suspicious **(3 Marks)**
# - Clarity and presentation **(2 Marks)**
#
# You should state all suspicious IP addresses that you have identified as part of your conclusion, and you should explain in clear written English how you have uncovered this information, based on how you have used Python code for data investigation. This should be clear and concise, and you only need to include code that helped you to solve the challenge.

# %% [markdown]
# # Catalog for Question # 10
# 1. Identifying all suspicious activity within your dataset <br>
#    1. 1.1 Check original data
#    2. 1.2 Investigate Suspicious IPs
#
# 2. Analytical reasoning for investigating why this activity is suspicious<br>
#       1. 2.1 A first list of suspicious users
#       2. 2.2 Suspicious c-ip # 1 - 89.38.127.38
#       3. 2.3 Check two different c-ip's with the same cs-uri-query
#       4. 2.4 Suspicious c-ip # 2 - 2.22.140.181
#       5. 2.5 Suspicious IP # 3 - 78.40.22.101
#       6. 2.6 List status 404 in January
#       7. 2.7 Suspicious usernames
#       8. 2.8 Suspicious c-ips
#       9. 2.9 List suspicious user's activites with status 200<br>
#
# 3. Clarity and presentation

# %% [markdown]
# # 1 Identifying all suspicious activity within your dataset

# %% [markdown]
# ## 1.1 Step 1. Check orginal data
# - Check Original data to find some suspicious elements as a starting point for investigation.
# - Check number of daily data/200/404

# %%
data
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 0       2023-01-01  00:24:00  167.167.244.11       GET       gtbmiuyo.css
# 1       2023-01-01  00:24:00  167.167.244.11       GET         index.aspx
# 2       2023-01-01  00:24:28  167.167.244.11       GET         favico.ico
# 3       2023-01-01  00:24:28  167.167.244.11       GET       gcjnjeej.css
# 4       2023-01-01  00:24:28  167.167.244.11       GET           main.css
# ...            ...       ...             ...       ...                ...
# 350591  2023-01-30  23:55:45  167.167.244.11       GET  transactions.aspx
# 350592  2023-01-30  23:56:06  167.167.244.11       GET         footer.css
# 350593  2023-01-30  23:56:06  167.167.244.11       GET        ttcsdmrb.js
# 350594  2023-01-30  23:56:06  167.167.244.11       GET       phekuflm.css
# 350595  2023-01-30  23:56:06  167.167.244.11       GET        logout.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 0                 -     443           -  34.189.170.188
# 1                 -     443           -  34.189.170.188
# 2                 -     443           -  34.189.170.188
# 3                 -     443           -  34.189.170.188
# 4                 -     443           -  34.189.170.188
# ...             ...     ...         ...             ...
# 350591       page=1     443    um821644    45.94.33.238
# 350592            -     443           -    45.94.33.238
# 350593     v=746817     443           -    45.94.33.238
# 350594            -     443           -    45.94.33.238
# 350595            -     443           -    45.94.33.238
#
#                                            cs(User-Agent)  \
# 0       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 1       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 2       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 3       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 4       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 350591  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350592  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350593  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350594  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 350595  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 0                                             -        200             0
# 1                                             -        200             0
# 2              https://uwetech.co.uk/index.aspx        200             0
# 3              https://uwetech.co.uk/index.aspx        404             0
# 4              https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 350591  https://uwetech.co.uk/transactions.aspx        200             0
# 350592  https://uwetech.co.uk/transactions.aspx        200             0
# 350593  https://uwetech.co.uk/transactions.aspx        200             0
# 350594  https://uwetech.co.uk/transactions.aspx        404             0
# 350595  https://uwetech.co.uk/transactions.aspx        301             0
#
#         sc-win32-status  time-taken            datetime
# 0                     0          27 2023-01-01 00:24:00
# 1                     0          22 2023-01-01 00:24:00
# 2                     0          23 2023-01-01 00:24:28
# 3                     0          23 2023-01-01 00:24:28
# 4                     0          29 2023-01-01 00:24:28
# ...                 ...         ...                 ...
# 350591                0          24 2023-01-30 23:55:45
# 350592                0          22 2023-01-30 23:56:06
# 350593                0          20 2023-01-30 23:56:06
# 350594                0          22 2023-01-30 23:56:06
# 350595                0          26 2023-01-30 23:56:06
#
# [350596 rows x 16 columns]

# %% [markdown]
# ### Daily 404 numbers

# %%
import datetime

# Initialize an empty dictionary
date_dict = {}

# Start date
start_date = datetime.date(2023, 1, 1)

# Iterate over the range from 1 to 31
for i in range(1, 31):
    # Calculate the date for the current iteration
    current_date = start_date + datetime.timedelta(days=i-1)
    if i < 10:
        xx = ab_df[(ab_df['sc-status'] == 404)&(ab_df['date'] == '2023-01-0'+str(i))]
    else:
        xx = ab_df[(ab_df['sc-status'] == 404)&(ab_df['date'] == '2023-01-'+str(i))]
    len_x = len(xx)
    # Add the date and corresponding number to the dictionary
    date_dict[current_date.strftime('%Y-%m-%d')] = len_x

# Print the dictionary
for key, value in date_dict.items():
    print(key, value)
# Out:
# 2023-01-01 23
# 2023-01-02 38
# 2023-01-03 19
# 2023-01-04 23
# 2023-01-05 19
# 2023-01-06 6
# 2023-01-07 20
# 2023-01-08 42
# 2023-01-09 40
# 2023-01-10 21
# 2023-01-11 26
# 2023-01-12 38
# 2023-01-13 23
# 2023-01-14 26
# 2023-01-15 39
# 2023-01-16 22
# 2023-01-17 12
# 2023-01-18 22
# 2023-01-19 32
# 2023-01-20 23
# 2023-01-21 36
# 2023-01-22 28
# 2023-01-23 52
# 2023-01-24 23
# 2023-01-25 36
# 2023-01-26 21
# 2023-01-27 30
# 2023-01-28 29
# 2023-01-29 22
# 2023-01-30 33

# %%
data['s-port'].value_counts()
# Out:
# s-port
# 443    350596
# Name: count, dtype: int64

# %%
data['s-ip'].value_counts()
# Out:
# s-ip
# 167.167.244.11    350596
# Name: count, dtype: int64

# %%
data['cs-uri-query'].value_counts()
# Out:
# cs-uri-query
# -                   245282
# page=2               18369
# page=1               10004
# page=3                6684
# page=4                4979
#                      ...
# v=107026                 1
# v=filyfzeu               1
# v=236042                 1
# accountid=369127         1
# v=746817                 1
# Name: count, Length: 59172, dtype: int64

# %%
data['c-ip'].value_counts()
# Out:
# c-ip
# 198.169.194.238    332
# 89.43.49.3         280
# 135.244.31.76      272
# 194.245.32.53      221
# 94.177.126.101     155
#                   ...
# 185.184.115.39      20
# 213.155.153.2       20
# 45.95.10.120        19
# 195.82.125.220      19
# 195.248.192.46      18
# Name: count, Length: 5048, dtype: int64

# %%
data['cs-username'].value_counts()
# Out:
# cs-username
# -           135714
# ik640020       117
# lb893196       111
# rl825368       110
# na648390       106
#              ...
# om315513         9
# sb219128         8
# hp204865         8
# nu294936         8
# lt292647         8
# Name: count, Length: 5048, dtype: int64

# %%
data['cs(Referer)'].value_counts()
# Out:
# cs(Referer)
# https://uwetech.co.uk/transactions.aspx         117177
# https://uwetech.co.uk/index.aspx                 90058
# https://uwetech.co.uk/login.aspx                 66459
# https://uwetech.co.uk/account_status.aspx        31088
# -                                                29955
# https://uwetech.co.uk/transfer.aspx               8782
# https://uwetech.co.uk/changepassword.aspx         3127
# https://uwetech.co.uk/faq.aspx                    1844
# https://uwetech.co.uk/transfer_complete.aspx      1496
# https://uwetech.co.uk/change_avatar.aspx           610
# Name: count, dtype: int64

# %%
data['cs-uri-query'].value_counts()
# Out:
# cs-uri-query
# -                   245282
# page=2               18369
# page=1               10004
# page=3                6684
# page=4                4979
#                      ...
# v=107026                 1
# v=filyfzeu               1
# v=236042                 1
# accountid=369127         1
# v=746817                 1
# Name: count, Length: 59172, dtype: int64

# %%
data['time-taken'].value_counts()
# Out:
# time-taken
# 21    32162
# 20    32139
# 28    32054
# 29    32041
# 27    31957
# 25    31900
# 24    31800
# 30    31778
# 26    31663
# 23    31604
# 22    31498
# Name: count, dtype: int64

# %%
data['cs-method'].value_counts()
# Out:
# cs-method
# GET     335854
# POST     14742
# Name: count, dtype: int64

# %% [markdown]
# # 1.2 Step 2. Investigate Suspicious IPs

# %% [markdown]
# ### 1.2.1 Check suspicious activities between 00:00 A.M. - 05:00 A.M.
# - Usually, the situation that status `200` follows after several `404` would be suspicious.
# - Search `cs-uri-query` contains `v=` which relates to a transaction.

# %%
df = pd.DataFrame(data)
ab_df = df[((df['sc-status'] == 200) | (df['sc-status'] == 404)) & (pd.to_datetime(df['time']) < pd.to_datetime('05:00:00')) ]
ab_df['cuq'] = ab_df['cs-uri-query']
ab_df['cuq'] = ab_df['cuq'].str.contains('v=', regex=True)
ab_df
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 0       2023-01-01  00:24:00  167.167.244.11       GET       gtbmiuyo.css
# 1       2023-01-01  00:24:00  167.167.244.11       GET         index.aspx
# 2       2023-01-01  00:24:28  167.167.244.11       GET         favico.ico
# 3       2023-01-01  00:24:28  167.167.244.11       GET       gcjnjeej.css
# 4       2023-01-01  00:24:28  167.167.244.11       GET           main.css
# ...            ...       ...             ...       ...                ...
# 339047  2023-01-30  04:42:12  167.167.244.11       GET  transactions.aspx
# 339048  2023-01-30  04:42:40  167.167.244.11       GET       duibcilt.css
# 339049  2023-01-30  04:42:40  167.167.244.11       GET         favico.ico
# 339050  2023-01-30  04:42:40  167.167.244.11       GET       template.css
# 339051  2023-01-30  04:42:40  167.167.244.11       GET  transactions.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 0                 -     443           -  34.189.170.188
# 1                 -     443           -  34.189.170.188
# 2                 -     443           -  34.189.170.188
# 3                 -     443           -  34.189.170.188
# 4                 -     443           -  34.189.170.188
# ...             ...     ...         ...             ...
# 339047       page=4     443    bv886889  194.31.146.177
# 339048            -     443    bv886889  194.31.146.177
# 339049            -     443    bv886889  194.31.146.177
# 339050   v=ppncyqqx     443    bv886889  194.31.146.177
# 339051       page=5     443    bv886889  194.31.146.177
#
#                                            cs(User-Agent)  \
# 0       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 1       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 2       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 3       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 4       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 339047  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 339048  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 339049  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 339050  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 339051  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 0                                             -        200             0
# 1                                             -        200             0
# 2              https://uwetech.co.uk/index.aspx        200             0
# 3              https://uwetech.co.uk/index.aspx        404             0
# 4              https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 339047  https://uwetech.co.uk/transactions.aspx        200             0
# 339048  https://uwetech.co.uk/transactions.aspx        200             0
# 339049  https://uwetech.co.uk/transactions.aspx        200             0
# 339050  https://uwetech.co.uk/transactions.aspx        200             0
# 339051  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 0                     0          27 2023-01-01 00:24:00  False
# 1                     0          22 2023-01-01 00:24:00  False
# 2                     0          23 2023-01-01 00:24:28  False
# 3                     0          23 2023-01-01 00:24:28  False
# 4                     0          29 2023-01-01 00:24:28  False
# ...                 ...         ...                 ...    ...
# 339047                0          23 2023-01-30 04:42:12  False
# 339048                0          24 2023-01-30 04:42:40  False
# 339049                0          20 2023-01-30 04:42:40  False
# 339050                0          26 2023-01-30 04:42:40   True
# 339051                0          21 2023-01-30 04:42:40  False
#
# [9058 rows x 17 columns]

# %% [markdown]
# ### 1.2.2 Check the date 2023-01-17
# - According to the line plot of Question 8, there was **the highest number of data** on `2023-01-17`, which is unusual.
# - The reason to start by search status `404`, is because the number of `404` is far less than `200`.
# - By doing so, the investigation arrangement can be shrunk down to a smaller area which is more convenient to look for suspicious activities.

# %%
a = ab_df[ab_df['date'] == '2023-01-17']
a[(ab_df['sc-status'] == 404)]
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 186230  2023-01-17  01:09:52  167.167.244.11       GET  rujwctff.css
# 186233  2023-01-17  01:10:16  167.167.244.11       GET  nxwevjus.css
# 186250  2023-01-17  01:11:50  167.167.244.11       GET  mhxbhkll.css
# 186255  2023-01-17  01:12:02  167.167.244.11       GET  rexmaklp.css
# 186264  2023-01-17  01:19:00  167.167.244.11       GET  dcxdjwlg.css
# 186273  2023-01-17  01:19:56  167.167.244.11       GET  remirxjb.css
# 186276  2023-01-17  01:20:24  167.167.244.11       GET  goddsame.css
# 186330  2023-01-17  02:04:51  167.167.244.11       GET  pwnarkym.css
# 186334  2023-01-17  03:26:00  167.167.244.11       GET  iysdkdvi.css
# 186339  2023-01-17  03:26:16  167.167.244.11       GET  ahfcdkhi.css
# 186362  2023-01-17  03:28:15  167.167.244.11       GET  wywujemb.css
# 186365  2023-01-17  03:28:28  167.167.244.11       GET  knmddmsz.css
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 186230            -     443           -    89.38.127.38
# 186233            -     443           -    89.38.127.38
# 186250            -     443    fs409009    89.38.127.38
# 186255            -     443    fs409009    89.38.127.38
# 186264            -     443           -  193.36.133.169
# 186273            -     443           -  193.36.133.169
# 186276            -     443    jk185153  193.36.133.169
# 186330            -     443    nr175198    129.36.142.7
# 186334            -     443           -    54.228.16.79
# 186339            -     443           -    54.228.16.79
# 186362            -     443    kn358979    54.228.16.79
# 186365            -     443           -  155.254.119.31
#
#                                            cs(User-Agent)  \
# 186230  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186233  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186250  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186255  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186264  Mozilla/5.0+(Windows+NT+6.3;+WOW64;+Trident/7....
# 186273  Mozilla/5.0+(Windows+NT+6.3;+WOW64;+Trident/7....
# 186276  Mozilla/5.0+(Windows+NT+6.3;+WOW64;+Trident/7....
# 186330  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_3+like+M...
# 186334  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_2+like+M...
# 186339  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_2+like+M...
# 186362  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_2+like+M...
# 186365  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_6+like+M...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 186230         https://uwetech.co.uk/index.aspx        404             0
# 186233         https://uwetech.co.uk/index.aspx        404             0
# 186250  https://uwetech.co.uk/transactions.aspx        404             0
# 186255  https://uwetech.co.uk/transactions.aspx        404             0
# 186264                                        -        404             0
# 186273         https://uwetech.co.uk/index.aspx        404             0
# 186276         https://uwetech.co.uk/login.aspx        404             0
# 186330  https://uwetech.co.uk/transactions.aspx        404             0
# 186334                                        -        404             0
# 186339         https://uwetech.co.uk/index.aspx        404             0
# 186362  https://uwetech.co.uk/transactions.aspx        404             0
# 186365         https://uwetech.co.uk/index.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 186230                0          21 2023-01-17 01:09:52  False
# 186233                0          28 2023-01-17 01:10:16  False
# 186250                0          23 2023-01-17 01:11:50  False
# 186255                0          24 2023-01-17 01:12:02  False
# 186264                0          29 2023-01-17 01:19:00  False
# 186273                0          22 2023-01-17 01:19:56  False
# 186276                0          28 2023-01-17 01:20:24  False
# 186330                0          28 2023-01-17 02:04:51  False
# 186334                0          24 2023-01-17 03:26:00  False
# 186339                0          28 2023-01-17 03:26:16  False
# 186362                0          29 2023-01-17 03:28:15  False
# 186365                0          23 2023-01-17 03:28:28  False

# %% [markdown]
# # 2.1 A first list of suspicious users
# - A user `fs409009` had failed to complete a transaction from `01:11:50` to `01:12:02`, frequent attempts within only 12 seconds are suspicious.
# - So I started investigating the user `fs409009`'s activities.
# - Other users `jk185153`, `nr175198` and `kn358979` had been checked, they were recognized as benign users so far.

# %%
a[(ab_df['cs-username'] == 'fs409009')]
# Out:
#               date      time            s-ip cs-method          cs-uri-stem  \
# 186236  2023-01-17  01:10:31  167.167.244.11       GET         ezrjkgfg.css
# 186237  2023-01-17  01:10:31  167.167.244.11       GET         yqhswzwc.css
# 186239  2023-01-17  01:10:45  167.167.244.11       GET           favico.ico
# 186240  2023-01-17  01:10:45  167.167.244.11       GET  account_status.aspx
# 186241  2023-01-17  01:10:51  167.167.244.11       GET          fjqgfcps.js
# ...            ...       ...             ...       ...                  ...
# 186253  2023-01-17  01:11:50  167.167.244.11       GET    transactions.aspx
# 186254  2023-01-17  01:12:02  167.167.244.11       GET         ngclebsv.css
# 186255  2023-01-17  01:12:02  167.167.244.11       GET         rexmaklp.css
# 186256  2023-01-17  01:12:02  167.167.244.11       GET         template.css
# 186257  2023-01-17  01:12:02  167.167.244.11       GET    transactions.aspx
#
#        cs-uri-query  s-port cs-username          c-ip  \
# 186236            -     443    fs409009  89.38.127.38
# 186237            -     443    fs409009  89.38.127.38
# 186239            -     443    fs409009  89.38.127.38
# 186240            -     443    fs409009  89.38.127.38
# 186241     v=412138     443    fs409009  89.38.127.38
# ...             ...     ...         ...           ...
# 186253       page=3     443    fs409009  89.38.127.38
# 186254            -     443    fs409009  89.38.127.38
# 186255            -     443    fs409009  89.38.127.38
# 186256   v=svbuxhkr     443    fs409009  89.38.127.38
# 186257       page=4     443    fs409009  89.38.127.38
#
#                                            cs(User-Agent)  \
# 186236  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186237  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186239  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186240  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186241  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# ...                                                   ...
# 186253  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186254  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186255  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186256  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186257  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 186236           https://uwetech.co.uk/login.aspx        200             0
# 186237           https://uwetech.co.uk/login.aspx        200             0
# 186239           https://uwetech.co.uk/login.aspx        200             0
# 186240           https://uwetech.co.uk/login.aspx        200             0
# 186241  https://uwetech.co.uk/account_status.aspx        200             0
# ...                                           ...        ...           ...
# 186253    https://uwetech.co.uk/transactions.aspx        200             0
# 186254    https://uwetech.co.uk/transactions.aspx        200             0
# 186255    https://uwetech.co.uk/transactions.aspx        404             0
# 186256    https://uwetech.co.uk/transactions.aspx        200             0
# 186257    https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 186236                0          24 2023-01-17 01:10:31  False
# 186237                0          28 2023-01-17 01:10:31  False
# 186239                0          29 2023-01-17 01:10:45  False
# 186240                0          23 2023-01-17 01:10:45  False
# 186241                0          21 2023-01-17 01:10:51   True
# ...                 ...         ...                 ...    ...
# 186253                0          28 2023-01-17 01:11:50  False
# 186254                0          23 2023-01-17 01:12:02  False
# 186255                0          24 2023-01-17 01:12:02  False
# 186256                0          24 2023-01-17 01:12:02   True
# 186257                0          23 2023-01-17 01:12:02  False
#
# [21 rows x 17 columns]

# %% [markdown]
# # 2.2 Suspicious c-ip # 1 - `89.38.127.38`
# - The user `fs409009` usually used c-ip `89.38.127.38` to interact with `https://uwetech.co.uk/`.
# - So I also checked relevant activities in filtered data `ab-df` and original data `df`.

# %%
a[(ab_df['c-ip'] == '89.38.127.38')]
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 186224  2023-01-17  01:09:00  167.167.244.11       GET           main.css
# 186225  2023-01-17  01:09:00  167.167.244.11       GET        hxuxeevz.js
# 186226  2023-01-17  01:09:00  167.167.244.11       GET         index.aspx
# 186227  2023-01-17  01:09:26  167.167.244.11       GET       kmkyakft.css
# 186228  2023-01-17  01:09:26  167.167.244.11       GET         index.aspx
# ...            ...       ...             ...       ...                ...
# 186256  2023-01-17  01:12:02  167.167.244.11       GET       template.css
# 186257  2023-01-17  01:12:02  167.167.244.11       GET  transactions.aspx
# 186258  2023-01-17  01:12:09  167.167.244.11       GET         favico.ico
# 186259  2023-01-17  01:12:09  167.167.244.11       GET       tmmhgkte.css
# 186260  2023-01-17  01:12:09  167.167.244.11       GET        gqyqxdoe.js
#
#        cs-uri-query  s-port cs-username          c-ip  \
# 186224            -     443           -  89.38.127.38
# 186225     v=275521     443           -  89.38.127.38
# 186226            -     443           -  89.38.127.38
# 186227            -     443           -  89.38.127.38
# 186228            -     443           -  89.38.127.38
# ...             ...     ...         ...           ...
# 186256   v=svbuxhkr     443    fs409009  89.38.127.38
# 186257       page=4     443    fs409009  89.38.127.38
# 186258            -     443           -  89.38.127.38
# 186259            -     443           -  89.38.127.38
# 186260     v=976726     443           -  89.38.127.38
#
#                                            cs(User-Agent)  \
# 186224  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186225  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186226  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186227  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186228  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# ...                                                   ...
# 186256  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186257  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186258  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186259  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186260  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 186224                                        -        200             0
# 186225                                        -        200             0
# 186226                                        -        200             0
# 186227         https://uwetech.co.uk/index.aspx        200             0
# 186228         https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 186256  https://uwetech.co.uk/transactions.aspx        200             0
# 186257  https://uwetech.co.uk/transactions.aspx        200             0
# 186258  https://uwetech.co.uk/transactions.aspx        200             0
# 186259  https://uwetech.co.uk/transactions.aspx        200             0
# 186260  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 186224                0          23 2023-01-17 01:09:00  False
# 186225                0          30 2023-01-17 01:09:00   True
# 186226                0          26 2023-01-17 01:09:00  False
# 186227                0          25 2023-01-17 01:09:26  False
# 186228                0          22 2023-01-17 01:09:26  False
# ...                 ...         ...                 ...    ...
# 186256                0          24 2023-01-17 01:12:02   True
# 186257                0          23 2023-01-17 01:12:02  False
# 186258                0          25 2023-01-17 01:12:09  False
# 186259                0          27 2023-01-17 01:12:09  False
# 186260                0          25 2023-01-17 01:12:09   True
#
# [35 rows x 17 columns]

# %% [markdown]
# ### A. Original data
# - Since there were too many `200` showing in the dataframe, so I went back to filtered data and searched `404` to find some clues .

# %%
a[(df['c-ip'] == '89.38.127.38')]
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 186224  2023-01-17  01:09:00  167.167.244.11       GET           main.css
# 186225  2023-01-17  01:09:00  167.167.244.11       GET        hxuxeevz.js
# 186226  2023-01-17  01:09:00  167.167.244.11       GET         index.aspx
# 186227  2023-01-17  01:09:26  167.167.244.11       GET       kmkyakft.css
# 186228  2023-01-17  01:09:26  167.167.244.11       GET         index.aspx
# ...            ...       ...             ...       ...                ...
# 186256  2023-01-17  01:12:02  167.167.244.11       GET       template.css
# 186257  2023-01-17  01:12:02  167.167.244.11       GET  transactions.aspx
# 186258  2023-01-17  01:12:09  167.167.244.11       GET         favico.ico
# 186259  2023-01-17  01:12:09  167.167.244.11       GET       tmmhgkte.css
# 186260  2023-01-17  01:12:09  167.167.244.11       GET        gqyqxdoe.js
#
#        cs-uri-query  s-port cs-username          c-ip  \
# 186224            -     443           -  89.38.127.38
# 186225     v=275521     443           -  89.38.127.38
# 186226            -     443           -  89.38.127.38
# 186227            -     443           -  89.38.127.38
# 186228            -     443           -  89.38.127.38
# ...             ...     ...         ...           ...
# 186256   v=svbuxhkr     443    fs409009  89.38.127.38
# 186257       page=4     443    fs409009  89.38.127.38
# 186258            -     443           -  89.38.127.38
# 186259            -     443           -  89.38.127.38
# 186260     v=976726     443           -  89.38.127.38
#
#                                            cs(User-Agent)  \
# 186224  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186225  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186226  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186227  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186228  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# ...                                                   ...
# 186256  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186257  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186258  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186259  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186260  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 186224                                        -        200             0
# 186225                                        -        200             0
# 186226                                        -        200             0
# 186227         https://uwetech.co.uk/index.aspx        200             0
# 186228         https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 186256  https://uwetech.co.uk/transactions.aspx        200             0
# 186257  https://uwetech.co.uk/transactions.aspx        200             0
# 186258  https://uwetech.co.uk/transactions.aspx        200             0
# 186259  https://uwetech.co.uk/transactions.aspx        200             0
# 186260  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 186224                0          23 2023-01-17 01:09:00  False
# 186225                0          30 2023-01-17 01:09:00   True
# 186226                0          26 2023-01-17 01:09:00  False
# 186227                0          25 2023-01-17 01:09:26  False
# 186228                0          22 2023-01-17 01:09:26  False
# ...                 ...         ...                 ...    ...
# 186256                0          24 2023-01-17 01:12:02   True
# 186257                0          23 2023-01-17 01:12:02  False
# 186258                0          25 2023-01-17 01:12:09  False
# 186259                0          27 2023-01-17 01:12:09  False
# 186260                0          25 2023-01-17 01:12:09   True
#
# [35 rows x 17 columns]

# %% [markdown]
# ### B. Filtered Data
# - There were 4 attempts in 3 minutes

# %%
bb = a[(ab_df['c-ip'] == '89.38.127.38')]
bb[bb['sc-status'] == 404]
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 186230  2023-01-17  01:09:52  167.167.244.11       GET  rujwctff.css
# 186233  2023-01-17  01:10:16  167.167.244.11       GET  nxwevjus.css
# 186250  2023-01-17  01:11:50  167.167.244.11       GET  mhxbhkll.css
# 186255  2023-01-17  01:12:02  167.167.244.11       GET  rexmaklp.css
#
#        cs-uri-query  s-port cs-username          c-ip  \
# 186230            -     443           -  89.38.127.38
# 186233            -     443           -  89.38.127.38
# 186250            -     443    fs409009  89.38.127.38
# 186255            -     443    fs409009  89.38.127.38
#
#                                            cs(User-Agent)  \
# 186230  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186233  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186250  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 186255  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 186230         https://uwetech.co.uk/index.aspx        404             0
# 186233         https://uwetech.co.uk/index.aspx        404             0
# 186250  https://uwetech.co.uk/transactions.aspx        404             0
# 186255  https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 186230                0          21 2023-01-17 01:09:52  False
# 186233                0          28 2023-01-17 01:10:16  False
# 186250                0          23 2023-01-17 01:11:50  False
# 186255                0          24 2023-01-17 01:12:02  False

# %% [markdown]
# ### C. Check the suspicious `cs-uri-query` sections
# - Check it in the filtered data `b` , to investigate all the records with transactions (`cs-uri-query` contains `v=`) from the filtered data `ab_df`

# %%
b = ab_df[ab_df['cuq'] == True ]
b
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 7       2023-01-01  00:24:46  167.167.244.11       GET  template.css
# 21      2023-01-01  00:26:26  167.167.244.11       GET   cvppenru.js
# 24      2023-01-01  00:26:50  167.167.244.11       GET   aucmigtu.js
# 30      2023-01-01  00:27:25  167.167.244.11       GET   btnjzjas.js
# 32      2023-01-01  00:27:25  167.167.244.11       GET  template.css
# ...            ...       ...             ...       ...           ...
# 339005  2023-01-30  04:31:17  167.167.244.11       GET  template.css
# 339008  2023-01-30  04:31:23  167.167.244.11       GET  template.css
# 339022  2023-01-30  04:39:49  167.167.244.11       GET   dbsufkeb.js
# 339040  2023-01-30  04:41:40  167.167.244.11       GET   zoevgkmw.js
# 339050  2023-01-30  04:42:40  167.167.244.11       GET  template.css
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 7        v=vbdhwsnk     443           -  34.189.170.188
# 21         v=385746     443    dd915907  34.189.170.188
# 24         v=529178     443    dd915907  34.189.170.188
# 30         v=389361     443    dd915907  34.189.170.188
# 32       v=cdpginre     443    dd915907  34.189.170.188
# ...             ...     ...         ...             ...
# 339005   v=rkmsnddm     443    jx481350  185.181.96.202
# 339008   v=fymdzikg     443    jx481350  185.181.96.202
# 339022     v=506049     443           -  194.31.146.177
# 339040     v=364092     443    bv886889  194.31.146.177
# 339050   v=ppncyqqx     443    bv886889  194.31.146.177
#
#                                            cs(User-Agent)  \
# 7       Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 21      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 24      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 30      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# 32      Mozilla/5.0+(iPhone;+CPU+iPhone+OS+11_4_1+like...
# ...                                                   ...
# 339005  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 339008  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 339022  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 339040  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 339050  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 7              https://uwetech.co.uk/index.aspx        200             0
# 21      https://uwetech.co.uk/transactions.aspx        200             0
# 24      https://uwetech.co.uk/transactions.aspx        200             0
# 30      https://uwetech.co.uk/transactions.aspx        200             0
# 32      https://uwetech.co.uk/transactions.aspx        200             0
# ...                                         ...        ...           ...
# 339005  https://uwetech.co.uk/transactions.aspx        200             0
# 339008  https://uwetech.co.uk/transactions.aspx        200             0
# 339022         https://uwetech.co.uk/index.aspx        200             0
# 339040  https://uwetech.co.uk/transactions.aspx        200             0
# 339050  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime   cuq
# 7                     0          21 2023-01-01 00:24:46  True
# 21                    0          23 2023-01-01 00:26:26  True
# 24                    0          30 2023-01-01 00:26:50  True
# 30                    0          26 2023-01-01 00:27:25  True
# 32                    0          24 2023-01-01 00:27:25  True
# ...                 ...         ...                 ...   ...
# 339005                0          27 2023-01-30 04:31:17  True
# 339008                0          26 2023-01-30 04:31:23  True
# 339022                0          23 2023-01-30 04:39:49  True
# 339040                0          29 2023-01-30 04:41:40  True
# 339050                0          26 2023-01-30 04:42:40  True
#
# [1610 rows x 17 columns]

# %% [markdown]
# ### D. Count the numbers of `cs-uri-query`'s values
# - Both `v=843338` & `v=356889` occured twice.

# %%
b['cs-uri-query'].value_counts()
# Out:
# cs-uri-query
# v=843338      2
# v=356889      2
# v=228545      1
# v=kqkpolnr    1
# v=txwgbhnv    1
#              ..
# v=873692      1
# v=127890      1
# v=tyrsirvx    1
# v=267717      1
# v=ppncyqqx    1
# Name: count, Length: 1608, dtype: int64

# %% [markdown]
# ### E. List the `c-ip`'s of the filtered data
# - Only list the top 20 to investigate the most suspicious `c-ip`s
# - But there were not enough clues to judge which `c-ip` needs to be investigated first.

# %%
ab_ips = b['c-ip'].value_counts().to_dict()
ab_first_20 = dict(list(ab_ips.items())[:20])
ab_first_20
# Out:
# {'195.78.111.37': 15,
#  '194.221.1.88': 13,
#  '185.205.30.57': 13,
#  '194.153.106.1': 13,
#  '185.206.227.90': 12,
#  '57.246.1.216': 12,
#  '195.149.186.132': 12,
#  '91.212.216.156': 12,
#  '32.58.111.210': 12,
#  '149.11.30.192': 11,
#  '45.11.178.32': 11,
#  '185.22.170.240': 11,
#  '185.120.7.169': 11,
#  '137.83.134.34': 11,
#  '91.225.16.24': 11,
#  '83.217.248.21': 11,
#  '185.168.55.28': 10,
#  '193.218.172.14': 10,
#  '193.108.69.166': 10,
#  '185.121.19.226': 10}

# %% [markdown]
# ### F. Only status `200` occured in the filtered data
# - There are too many `200` in the data `b`
# - I decided to go back to the filtered data `ab_df` which contains both `200` and `404`.

# %%
b['sc-status'].value_counts()
# Out:
# sc-status
# 200    1610
# Name: count, dtype: int64

# %% [markdown]
# ### G. `v=843338` seems benign
# - After being investigated both in the filtered data `ab_df` and original data `data`, transaction query `v=843338` seems benign.

# %%
m2 = ab_df[ab_df['cs-uri-query'] == 'v=843338']
m2
# Out:
#               date      time            s-ip cs-method  cs-uri-stem  \
# 174923  2023-01-16  01:29:38  167.167.244.11       GET  hvjdsdjf.js
# 246997  2023-01-22  02:19:06  167.167.244.11       GET  rmlhvmqo.js
#
#        cs-uri-query  s-port cs-username         c-ip  \
# 174923     v=843338     443           -  207.54.88.2
# 246997     v=843338     443    yb371329  31.3.244.34
#
#                                            cs(User-Agent)  \
# 174923  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 246997  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_0+like+M...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 174923         https://uwetech.co.uk/index.aspx        200             0
# 246997  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime   cuq
# 174923                0          20 2023-01-16 01:29:38  True
# 246997                0          20 2023-01-22 02:19:06  True

# %% [markdown]
# # 2.3 Check two different `c-ip`s with the same `cs-uri-query`
# - There are two different `c-ip`s, `207.54.88.2` & `31.3.244.34`
# - The user`207.54.88.2` (no username) made the same cs-uri-query `v=843338` as the user `31.3.244.34` (yb371329).

# %%
m2_1 = data[data['cs-uri-query'] == 'v=843338']
m2_1
# Out:
#               date      time            s-ip cs-method  cs-uri-stem  \
# 174923  2023-01-16  01:29:38  167.167.244.11       GET  hvjdsdjf.js
# 246997  2023-01-22  02:19:06  167.167.244.11       GET  rmlhvmqo.js
#
#        cs-uri-query  s-port cs-username         c-ip  \
# 174923     v=843338     443           -  207.54.88.2
# 246997     v=843338     443    yb371329  31.3.244.34
#
#                                            cs(User-Agent)  \
# 174923  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 246997  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_0+like+M...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 174923         https://uwetech.co.uk/index.aspx        200             0
# 246997  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 174923                0          20 2023-01-16 01:29:38
# 246997                0          20 2023-01-22 02:19:06

# %% [markdown]
# ### A. Investigate `207.54.88.2`
# - `207.54.88.2` made 34 activities on `2023-01-16` from 01:29:00 A.M. to 01:32:16 A.M.
# - Sometimes logged in as the user `vw112707`

# %%
m3 = ab_df[ab_df['c-ip'] == '207.54.88.2']
m3
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 174914  2023-01-16  01:29:00  167.167.244.11       GET       zrlybqgy.css
# 174915  2023-01-16  01:29:00  167.167.244.11       GET         favico.ico
# 174916  2023-01-16  01:29:00  167.167.244.11       GET       rbcepdvz.css
# 174917  2023-01-16  01:29:00  167.167.244.11       GET         index.aspx
# 174918  2023-01-16  01:29:24  167.167.244.11       GET        oqjkljfm.js
# ...            ...       ...             ...       ...                ...
# 174945  2023-01-16  01:31:56  167.167.244.11       GET       enbgdufd.css
# 174946  2023-01-16  01:31:56  167.167.244.11       GET         footer.css
# 174947  2023-01-16  01:31:56  167.167.244.11       GET  transactions.aspx
# 174948  2023-01-16  01:32:16  167.167.244.11       GET       template.css
# 174949  2023-01-16  01:32:16  167.167.244.11       GET  transactions.aspx
#
#        cs-uri-query  s-port cs-username         c-ip  \
# 174914            -     443           -  207.54.88.2
# 174915            -     443           -  207.54.88.2
# 174916            -     443           -  207.54.88.2
# 174917            -     443           -  207.54.88.2
# 174918     v=942144     443           -  207.54.88.2
# ...             ...     ...         ...          ...
# 174945            -     443    vw112707  207.54.88.2
# 174946            -     443    vw112707  207.54.88.2
# 174947       page=4     443    vw112707  207.54.88.2
# 174948   v=kicgtpjj     443    vw112707  207.54.88.2
# 174949       page=5     443    vw112707  207.54.88.2
#
#                                            cs(User-Agent)  \
# 174914  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174915  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174916  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174917  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174918  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# ...                                                   ...
# 174945  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174946  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174947  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174948  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174949  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 174914                                        -        200             0
# 174915                                        -        200             0
# 174916                                        -        200             0
# 174917                                        -        200             0
# 174918         https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 174945  https://uwetech.co.uk/transactions.aspx        200             0
# 174946  https://uwetech.co.uk/transactions.aspx        200             0
# 174947  https://uwetech.co.uk/transactions.aspx        200             0
# 174948  https://uwetech.co.uk/transactions.aspx        200             0
# 174949  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 174914                0          22 2023-01-16 01:29:00  False
# 174915                0          22 2023-01-16 01:29:00  False
# 174916                0          22 2023-01-16 01:29:00  False
# 174917                0          24 2023-01-16 01:29:00  False
# 174918                0          29 2023-01-16 01:29:24   True
# ...                 ...         ...                 ...    ...
# 174945                0          30 2023-01-16 01:31:56  False
# 174946                0          22 2023-01-16 01:31:56  False
# 174947                0          23 2023-01-16 01:31:56  False
# 174948                0          24 2023-01-16 01:32:16   True
# 174949                0          21 2023-01-16 01:32:16  False
#
# [34 rows x 17 columns]

# %% [markdown]
# ### B. `404` failed attempts
# - There were 2 suspicious attempts on `2023-01-16` at midnight from `01:29:24` A.M. to `01:31:10` A.M.

# %%
m3[m3['sc-status'] == 404]
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 174920  2023-01-16  01:29:24  167.167.244.11       GET  mmyqdktp.css
# 174935  2023-01-16  01:31:10  167.167.244.11       GET  hbbhhtkv.css
#
#        cs-uri-query  s-port cs-username         c-ip  \
# 174920            -     443           -  207.54.88.2
# 174935            -     443    vw112707  207.54.88.2
#
#                                            cs(User-Agent)  \
# 174920  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174935  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 174920         https://uwetech.co.uk/index.aspx        404             0
# 174935  https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 174920                0          23 2023-01-16 01:29:24  False
# 174935                0          29 2023-01-16 01:31:10  False

# %% [markdown]
# ### Normal loggin?
# -`207.54.88.2` logged in as the user `vw112707`

# %%
m31 = ab_df[ab_df['cs-username'] == 'vw112707']
m31
# Out:
#               date      time            s-ip cs-method          cs-uri-stem  \
# 174927  2023-01-16  01:30:24  167.167.244.11       GET         dyiefrho.css
# 174928  2023-01-16  01:30:24  167.167.244.11       GET         template.css
# 174929  2023-01-16  01:30:24  167.167.244.11       GET          ognwqual.js
# 174931  2023-01-16  01:30:46  167.167.244.11       GET          vgpqvaye.js
# 174932  2023-01-16  01:30:46  167.167.244.11       GET  account_status.aspx
# ...            ...       ...             ...       ...                  ...
# 174945  2023-01-16  01:31:56  167.167.244.11       GET         enbgdufd.css
# 174946  2023-01-16  01:31:56  167.167.244.11       GET           footer.css
# 174947  2023-01-16  01:31:56  167.167.244.11       GET    transactions.aspx
# 174948  2023-01-16  01:32:16  167.167.244.11       GET         template.css
# 174949  2023-01-16  01:32:16  167.167.244.11       GET    transactions.aspx
#
#        cs-uri-query  s-port cs-username         c-ip  \
# 174927            -     443    vw112707  207.54.88.2
# 174928   v=cxojvhus     443    vw112707  207.54.88.2
# 174929     v=142875     443    vw112707  207.54.88.2
# 174931     v=565705     443    vw112707  207.54.88.2
# 174932            -     443    vw112707  207.54.88.2
# ...             ...     ...         ...          ...
# 174945            -     443    vw112707  207.54.88.2
# 174946            -     443    vw112707  207.54.88.2
# 174947       page=4     443    vw112707  207.54.88.2
# 174948   v=kicgtpjj     443    vw112707  207.54.88.2
# 174949       page=5     443    vw112707  207.54.88.2
#
#                                            cs(User-Agent)  \
# 174927  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174928  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174929  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174931  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174932  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# ...                                                   ...
# 174945  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174946  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174947  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174948  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174949  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 174927         https://uwetech.co.uk/login.aspx        200             0
# 174928         https://uwetech.co.uk/login.aspx        200             0
# 174929         https://uwetech.co.uk/login.aspx        200             0
# 174931         https://uwetech.co.uk/login.aspx        200             0
# 174932         https://uwetech.co.uk/login.aspx        200             0
# ...                                         ...        ...           ...
# 174945  https://uwetech.co.uk/transactions.aspx        200             0
# 174946  https://uwetech.co.uk/transactions.aspx        200             0
# 174947  https://uwetech.co.uk/transactions.aspx        200             0
# 174948  https://uwetech.co.uk/transactions.aspx        200             0
# 174949  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 174927                0          24 2023-01-16 01:30:24  False
# 174928                0          22 2023-01-16 01:30:24   True
# 174929                0          27 2023-01-16 01:30:24   True
# 174931                0          29 2023-01-16 01:30:46   True
# 174932                0          30 2023-01-16 01:30:46  False
# ...                 ...         ...                 ...    ...
# 174945                0          30 2023-01-16 01:31:56  False
# 174946                0          22 2023-01-16 01:31:56  False
# 174947                0          23 2023-01-16 01:31:56  False
# 174948                0          24 2023-01-16 01:32:16   True
# 174949                0          21 2023-01-16 01:32:16  False
#
# [22 rows x 17 columns]

# %% [markdown]
# ### C. Suspicious transcations on `2023-01-16`

# %%
m3[pd.to_datetime(m3['time']) < pd.to_datetime('01:40:00')].head()
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 174914  2023-01-16  01:29:00  167.167.244.11       GET  zrlybqgy.css
# 174915  2023-01-16  01:29:00  167.167.244.11       GET    favico.ico
# 174916  2023-01-16  01:29:00  167.167.244.11       GET  rbcepdvz.css
# 174917  2023-01-16  01:29:00  167.167.244.11       GET    index.aspx
# 174918  2023-01-16  01:29:24  167.167.244.11       GET   oqjkljfm.js
#
#        cs-uri-query  s-port cs-username         c-ip  \
# 174914            -     443           -  207.54.88.2
# 174915            -     443           -  207.54.88.2
# 174916            -     443           -  207.54.88.2
# 174917            -     443           -  207.54.88.2
# 174918     v=942144     443           -  207.54.88.2
#
#                                            cs(User-Agent)  \
# 174914  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174915  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174916  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174917  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 174918  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
#
#                              cs(Referer)  sc-status  sc-substatus  \
# 174914                                 -        200             0
# 174915                                 -        200             0
# 174916                                 -        200             0
# 174917                                 -        200             0
# 174918  https://uwetech.co.uk/index.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 174914                0          22 2023-01-16 01:29:00  False
# 174915                0          22 2023-01-16 01:29:00  False
# 174916                0          22 2023-01-16 01:29:00  False
# 174917                0          24 2023-01-16 01:29:00  False
# 174918                0          29 2023-01-16 01:29:24   True

# %% [markdown]
# ### D. Investigate `31.3.244.34`

# %%
m4 = data[data['c-ip'] == '31.3.244.34']
m4.head()
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 134717  2023-01-12  12:57:00  167.167.244.11       GET    footer.css
# 134718  2023-01-12  12:57:00  167.167.244.11       GET   ohqcwwaz.js
# 134719  2023-01-12  12:57:00  167.167.244.11       GET  uvgkpuvw.css
# 134720  2023-01-12  12:57:00  167.167.244.11       GET    index.aspx
# 134721  2023-01-12  12:57:07  167.167.244.11       GET  rhvpuvei.css
#
#        cs-uri-query  s-port cs-username         c-ip  \
# 134717            -     443           -  31.3.244.34
# 134718     v=470600     443           -  31.3.244.34
# 134719            -     443           -  31.3.244.34
# 134720            -     443           -  31.3.244.34
# 134721            -     443           -  31.3.244.34
#
#                                            cs(User-Agent)  \
# 134717  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_0+like+M...
# 134718  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_0+like+M...
# 134719  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_0+like+M...
# 134720  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_0+like+M...
# 134721  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_0+like+M...
#
#                              cs(Referer)  sc-status  sc-substatus  \
# 134717                                 -        200             0
# 134718                                 -        200             0
# 134719                                 -        200             0
# 134720                                 -        200             0
# 134721  https://uwetech.co.uk/index.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 134717                0          20 2023-01-12 12:57:00
# 134718                0          21 2023-01-12 12:57:00
# 134719                0          27 2023-01-12 12:57:00
# 134720                0          21 2023-01-12 12:57:00
# 134721                0          23 2023-01-12 12:57:07

# %% [markdown]
# ### E. Investigate the cs-uri-query `v=843338`
# - So far, I can only ensure the cs-uri-query `v=843338` succeeded between `207.54.88.2` & `31.3.244.34`

# %%
m5 = data[data['cs-uri-query'] == 'v=843338']
m5
# Out:
#               date      time            s-ip cs-method  cs-uri-stem  \
# 174923  2023-01-16  01:29:38  167.167.244.11       GET  hvjdsdjf.js
# 246997  2023-01-22  02:19:06  167.167.244.11       GET  rmlhvmqo.js
#
#        cs-uri-query  s-port cs-username         c-ip  \
# 174923     v=843338     443           -  207.54.88.2
# 246997     v=843338     443    yb371329  31.3.244.34
#
#                                            cs(User-Agent)  \
# 174923  Mozilla/5.0+(Windows+NT+10.0;+WOW64;+Trident/7...
# 246997  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_0+like+M...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 174923         https://uwetech.co.uk/index.aspx        200             0
# 246997  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 174923                0          20 2023-01-16 01:29:38
# 246997                0          20 2023-01-22 02:19:06

# %% [markdown]
# # 2.4 Suspicious c-ip # 2 - `2.22.140.181`
# - The username `up356345`
# - The most suspicious activities occured on `2023-01-04`
# - `404`: 8 failed attempts from 02:49:12 - 02:52:07
# - `200`: 30 successful attempts from 02:49:00 - 02:52:07

# %%
m6 = data[(data['sc-status'] == 404) & (data['date'] == '2023-01-14') & ((pd.to_datetime(df['time']) < pd.to_datetime('05:00:00')))]
m6['cs-username'].value_counts()
# Out:
# cs-username
# -           7
# up356345    5
# hg463223    4
# fs975715    3
# nm403818    2
# cy656870    2
# jt677455    2
# rt234918    1
# Name: count, dtype: int64

# %%
m6['c-ip'].value_counts()
# Out:
# c-ip
# 2.22.140.181      8
# 78.40.22.101      5
# 45.11.178.32      3
# 23.5.162.118      3
# 217.140.99.50     3
# 13.107.246.44     2
# 91.245.226.126    2
# Name: count, dtype: int64

# %% [markdown]
# ### Check activities of `2.22.140.181`
# - There were 38 activities.
# - The most suspicious date occured on `2023-01-14`
# - `404`: 8 attempts at midnight then succeeded for login & transaction.
# - `200`: 30 attempts succeeded at midnight.

# %%
m8 = ab_df[(ab_df['c-ip'] == '2.22.140.181')]
len(m8)
# Out:
# 38

# %%
m8[m8['sc-status'] == 404]
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 151159  2023-01-14  02:49:12  167.167.244.11       GET  mdecbmsl.css
# 151161  2023-01-14  02:49:12  167.167.244.11       GET  swpqqtie.css
# 151164  2023-01-14  02:49:33  167.167.244.11       GET  thhsltve.css
# 151169  2023-01-14  02:50:15  167.167.244.11       GET  ydxumjhw.css
# 151171  2023-01-14  02:50:15  167.167.244.11       GET  hitjshts.css
# 151174  2023-01-14  02:50:42  167.167.244.11       GET  zyjlkcja.css
# 151185  2023-01-14  02:51:46  167.167.244.11       GET  pzxetemo.css
# 151194  2023-01-14  02:52:07  167.167.244.11       GET  lmftflwg.css
#
#        cs-uri-query  s-port cs-username          c-ip  \
# 151159            -     443           -  2.22.140.181
# 151161            -     443           -  2.22.140.181
# 151164            -     443           -  2.22.140.181
# 151169            -     443    up356345  2.22.140.181
# 151171            -     443    up356345  2.22.140.181
# 151174            -     443    up356345  2.22.140.181
# 151185            -     443    up356345  2.22.140.181
# 151194            -     443    up356345  2.22.140.181
#
#                                            cs(User-Agent)  \
# 151159  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151161  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151164  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151169  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151171  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151174  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151185  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151194  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 151159         https://uwetech.co.uk/index.aspx        404             0
# 151161         https://uwetech.co.uk/index.aspx        404             0
# 151164         https://uwetech.co.uk/index.aspx        404             0
# 151169         https://uwetech.co.uk/login.aspx        404             0
# 151171         https://uwetech.co.uk/login.aspx        404             0
# 151174         https://uwetech.co.uk/login.aspx        404             0
# 151185  https://uwetech.co.uk/transactions.aspx        404             0
# 151194  https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 151159                0          20 2023-01-14 02:49:12  False
# 151161                0          25 2023-01-14 02:49:12  False
# 151164                0          22 2023-01-14 02:49:33  False
# 151169                0          26 2023-01-14 02:50:15  False
# 151171                0          21 2023-01-14 02:50:15  False
# 151174                0          30 2023-01-14 02:50:42  False
# 151185                0          23 2023-01-14 02:51:46  False
# 151194                0          30 2023-01-14 02:52:07  False

# %%
m8[(m8['sc-status'] == 200) & (m8['date'] == '2023-01-14')]
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 151156  2023-01-14  02:49:00  167.167.244.11       GET       pisvouxb.css
# 151157  2023-01-14  02:49:00  167.167.244.11       GET         favico.ico
# 151158  2023-01-14  02:49:00  167.167.244.11       GET         index.aspx
# 151160  2023-01-14  02:49:12  167.167.244.11       GET       wvjgkfkn.css
# 151162  2023-01-14  02:49:12  167.167.244.11       GET         index.aspx
# ...            ...       ...             ...       ...                ...
# 151190  2023-01-14  02:52:01  167.167.244.11       GET         favico.ico
# 151191  2023-01-14  02:52:01  167.167.244.11       GET         footer.css
# 151192  2023-01-14  02:52:01  167.167.244.11       GET  transactions.aspx
# 151193  2023-01-14  02:52:07  167.167.244.11       GET         favico.ico
# 151195  2023-01-14  02:52:07  167.167.244.11       GET  transactions.aspx
#
#        cs-uri-query  s-port cs-username          c-ip  \
# 151156            -     443           -  2.22.140.181
# 151157            -     443           -  2.22.140.181
# 151158            -     443           -  2.22.140.181
# 151160            -     443           -  2.22.140.181
# 151162            -     443           -  2.22.140.181
# ...             ...     ...         ...           ...
# 151190            -     443    up356345  2.22.140.181
# 151191            -     443    up356345  2.22.140.181
# 151192       page=4     443    up356345  2.22.140.181
# 151193            -     443    up356345  2.22.140.181
# 151195       page=5     443    up356345  2.22.140.181
#
#                                            cs(User-Agent)  \
# 151156  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151157  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151158  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151160  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151162  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# ...                                                   ...
# 151190  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151191  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151192  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151193  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
# 151195  Mozilla/5.0+(Windows+NT+6.1;+WOW64)+AppleWebKi...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 151156                                        -        200             0
# 151157                                        -        200             0
# 151158                                        -        200             0
# 151160         https://uwetech.co.uk/index.aspx        200             0
# 151162         https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 151190  https://uwetech.co.uk/transactions.aspx        200             0
# 151191  https://uwetech.co.uk/transactions.aspx        200             0
# 151192  https://uwetech.co.uk/transactions.aspx        200             0
# 151193  https://uwetech.co.uk/transactions.aspx        200             0
# 151195  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 151156                0          23 2023-01-14 02:49:00  False
# 151157                0          26 2023-01-14 02:49:00  False
# 151158                0          27 2023-01-14 02:49:00  False
# 151160                0          22 2023-01-14 02:49:12  False
# 151162                0          23 2023-01-14 02:49:12  False
# ...                 ...         ...                 ...    ...
# 151190                0          25 2023-01-14 02:52:01  False
# 151191                0          21 2023-01-14 02:52:01  False
# 151192                0          29 2023-01-14 02:52:01  False
# 151193                0          30 2023-01-14 02:52:07  False
# 151195                0          23 2023-01-14 02:52:07  False
#
# [30 rows x 17 columns]

# %% [markdown]
# # 2.5 Suspicious IP # 3 - `78.40.22.101`
# - The username is `hg463223`
# - The most suspicious date occured on `2023-01-14`
# - `404`: 4 failed attempts at midnight then succeeded for login & transaction.
# - `202`: 29 attempts succeeded at midnight.

# %%
m7 = data[data['cs-username'] == 'hg463223']
m7
# Out:
#               date      time            s-ip cs-method  \
# 151271  2023-01-14  04:41:03  167.167.244.11       GET
# 151272  2023-01-14  04:41:03  167.167.244.11       GET
# 151273  2023-01-14  04:41:03  167.167.244.11       GET
# 151274  2023-01-14  04:41:03  167.167.244.11      POST
# 151275  2023-01-14  04:41:09  167.167.244.11       GET
# ...            ...       ...             ...       ...
# 151300  2023-01-14  04:43:06  167.167.244.11       GET
# 151301  2023-01-14  04:43:06  167.167.244.11      POST
# 151302  2023-01-14  04:43:36  167.167.244.11       GET
# 151303  2023-01-14  04:43:36  167.167.244.11       GET
# 151304  2023-01-14  04:43:36  167.167.244.11       GET
#
#                    cs-uri-stem      cs-uri-query  s-port cs-username  \
# 151271            cavksenn.css                 -     443    hg463223
# 151272            cwiyhchx.css                 -     443    hg463223
# 151273            ailfzdgc.css                 -     443    hg463223
# 151274              login.aspx                 -     443    hg463223
# 151275                main.css                 -     443    hg463223
# ...                        ...               ...     ...         ...
# 151300            template.css        v=cibfypuc     443    hg463223
# 151301           transfer.aspx  accountid=668028     443    hg463223
# 151302            template.css        v=zezbvvtm     443    hg463223
# 151303             tjvnmusr.js          v=996105     443    hg463223
# 151304  transfer_complete.aspx                 -     443    hg463223
#
#                 c-ip                                     cs(User-Agent)  \
# 151271  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151272  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151273  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151274  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151275  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# ...              ...                                                ...
# 151300  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151301  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151302  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151303  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151304  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                 cs(Referer)  sc-status  sc-substatus  \
# 151271     https://uwetech.co.uk/login.aspx        200             0
# 151272     https://uwetech.co.uk/login.aspx        404             0
# 151273     https://uwetech.co.uk/login.aspx        200             0
# 151274     https://uwetech.co.uk/login.aspx        301             0
# 151275     https://uwetech.co.uk/login.aspx        200             0
# ...                                     ...        ...           ...
# 151300  https://uwetech.co.uk/transfer.aspx        200             0
# 151301  https://uwetech.co.uk/transfer.aspx        200             0
# 151302  https://uwetech.co.uk/transfer.aspx        200             0
# 151303  https://uwetech.co.uk/transfer.aspx        200             0
# 151304  https://uwetech.co.uk/transfer.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 151271                0          30 2023-01-14 04:41:03
# 151272                0          27 2023-01-14 04:41:03
# 151273                0          22 2023-01-14 04:41:03
# 151274                0          23 2023-01-14 04:41:03
# 151275                0          21 2023-01-14 04:41:09
# ...                 ...         ...                 ...
# 151300                0          28 2023-01-14 04:43:06
# 151301                0          26 2023-01-14 04:43:06
# 151302                0          27 2023-01-14 04:43:36
# 151303                0          28 2023-01-14 04:43:36
# 151304                0          28 2023-01-14 04:43:36
#
# [34 rows x 16 columns]

# %%
m7['c-ip'].unique()
# Out:
# array(['78.40.22.101'], dtype=object)

# %%
m7['sc-status'].value_counts()
# Out:
# sc-status
# 200    29
# 404     4
# 301     1
# Name: count, dtype: int64

# %%
m7[(data['sc-status'] == 404)]
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 151272  2023-01-14  04:41:03  167.167.244.11       GET  cwiyhchx.css
# 151286  2023-01-14  04:42:11  167.167.244.11       GET  vsvndsez.css
# 151295  2023-01-14  04:42:55  167.167.244.11       GET  welcidih.css
# 151298  2023-01-14  04:43:06  167.167.244.11       GET  nctohcyq.css
#
#        cs-uri-query  s-port cs-username          c-ip  \
# 151272            -     443    hg463223  78.40.22.101
# 151286            -     443    hg463223  78.40.22.101
# 151295            -     443    hg463223  78.40.22.101
# 151298            -     443    hg463223  78.40.22.101
#
#                                            cs(User-Agent)  \
# 151272  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151286  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151295  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151298  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 151272         https://uwetech.co.uk/login.aspx        404             0
# 151286  https://uwetech.co.uk/transactions.aspx        404             0
# 151295  https://uwetech.co.uk/transactions.aspx        404             0
# 151298      https://uwetech.co.uk/transfer.aspx        404             0
#
#         sc-win32-status  time-taken            datetime
# 151272                0          27 2023-01-14 04:41:03
# 151286                0          24 2023-01-14 04:42:11
# 151295                0          29 2023-01-14 04:42:55
# 151298                0          26 2023-01-14 04:43:06

# %%
m7[(data['sc-status'] == 200)]
# Out:
#               date      time            s-ip cs-method  \
# 151271  2023-01-14  04:41:03  167.167.244.11       GET
# 151273  2023-01-14  04:41:03  167.167.244.11       GET
# 151275  2023-01-14  04:41:09  167.167.244.11       GET
# 151276  2023-01-14  04:41:09  167.167.244.11       GET
# 151277  2023-01-14  04:41:09  167.167.244.11       GET
# ...            ...       ...             ...       ...
# 151300  2023-01-14  04:43:06  167.167.244.11       GET
# 151301  2023-01-14  04:43:06  167.167.244.11      POST
# 151302  2023-01-14  04:43:36  167.167.244.11       GET
# 151303  2023-01-14  04:43:36  167.167.244.11       GET
# 151304  2023-01-14  04:43:36  167.167.244.11       GET
#
#                    cs-uri-stem      cs-uri-query  s-port cs-username  \
# 151271            cavksenn.css                 -     443    hg463223
# 151273            ailfzdgc.css                 -     443    hg463223
# 151275                main.css                 -     443    hg463223
# 151276                main.css                 -     443    hg463223
# 151277     account_status.aspx                 -     443    hg463223
# ...                        ...               ...     ...         ...
# 151300            template.css        v=cibfypuc     443    hg463223
# 151301           transfer.aspx  accountid=668028     443    hg463223
# 151302            template.css        v=zezbvvtm     443    hg463223
# 151303             tjvnmusr.js          v=996105     443    hg463223
# 151304  transfer_complete.aspx                 -     443    hg463223
#
#                 c-ip                                     cs(User-Agent)  \
# 151271  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151273  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151275  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151276  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151277  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# ...              ...                                                ...
# 151300  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151301  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151302  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151303  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151304  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                 cs(Referer)  sc-status  sc-substatus  \
# 151271     https://uwetech.co.uk/login.aspx        200             0
# 151273     https://uwetech.co.uk/login.aspx        200             0
# 151275     https://uwetech.co.uk/login.aspx        200             0
# 151276     https://uwetech.co.uk/login.aspx        200             0
# 151277     https://uwetech.co.uk/login.aspx        200             0
# ...                                     ...        ...           ...
# 151300  https://uwetech.co.uk/transfer.aspx        200             0
# 151301  https://uwetech.co.uk/transfer.aspx        200             0
# 151302  https://uwetech.co.uk/transfer.aspx        200             0
# 151303  https://uwetech.co.uk/transfer.aspx        200             0
# 151304  https://uwetech.co.uk/transfer.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 151271                0          30 2023-01-14 04:41:03
# 151273                0          22 2023-01-14 04:41:03
# 151275                0          21 2023-01-14 04:41:09
# 151276                0          24 2023-01-14 04:41:09
# 151277                0          28 2023-01-14 04:41:09
# ...                 ...         ...                 ...
# 151300                0          28 2023-01-14 04:43:06
# 151301                0          26 2023-01-14 04:43:06
# 151302                0          27 2023-01-14 04:43:36
# 151303                0          28 2023-01-14 04:43:36
# 151304                0          28 2023-01-14 04:43:36
#
# [29 rows x 16 columns]

# %%
m9 = data[(data['c-ip'] == '78.40.22.101')]
m9
# Out:
#               date      time            s-ip cs-method  \
# 151258  2023-01-14  04:40:00  167.167.244.11       GET
# 151259  2023-01-14  04:40:00  167.167.244.11       GET
# 151260  2023-01-14  04:40:10  167.167.244.11       GET
# 151261  2023-01-14  04:40:10  167.167.244.11       GET
# 151262  2023-01-14  04:40:10  167.167.244.11       GET
# ...            ...       ...             ...       ...
# 151300  2023-01-14  04:43:06  167.167.244.11       GET
# 151301  2023-01-14  04:43:06  167.167.244.11      POST
# 151302  2023-01-14  04:43:36  167.167.244.11       GET
# 151303  2023-01-14  04:43:36  167.167.244.11       GET
# 151304  2023-01-14  04:43:36  167.167.244.11       GET
#
#                    cs-uri-stem      cs-uri-query  s-port cs-username  \
# 151258            grbrijln.css                 -     443           -
# 151259              index.aspx                 -     443           -
# 151260            template.css        v=ggwcnbru     443           -
# 151261            bgumwlja.css                 -     443           -
# 151262              footer.css                 -     443           -
# ...                        ...               ...     ...         ...
# 151300            template.css        v=cibfypuc     443    hg463223
# 151301           transfer.aspx  accountid=668028     443    hg463223
# 151302            template.css        v=zezbvvtm     443    hg463223
# 151303             tjvnmusr.js          v=996105     443    hg463223
# 151304  transfer_complete.aspx                 -     443    hg463223
#
#                 c-ip                                     cs(User-Agent)  \
# 151258  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151259  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151260  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151261  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151262  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# ...              ...                                                ...
# 151300  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151301  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151302  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151303  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151304  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                 cs(Referer)  sc-status  sc-substatus  \
# 151258                                    -        200             0
# 151259                                    -        200             0
# 151260     https://uwetech.co.uk/index.aspx        200             0
# 151261     https://uwetech.co.uk/index.aspx        200             0
# 151262     https://uwetech.co.uk/index.aspx        200             0
# ...                                     ...        ...           ...
# 151300  https://uwetech.co.uk/transfer.aspx        200             0
# 151301  https://uwetech.co.uk/transfer.aspx        200             0
# 151302  https://uwetech.co.uk/transfer.aspx        200             0
# 151303  https://uwetech.co.uk/transfer.aspx        200             0
# 151304  https://uwetech.co.uk/transfer.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 151258                0          27 2023-01-14 04:40:00
# 151259                0          24 2023-01-14 04:40:00
# 151260                0          27 2023-01-14 04:40:10
# 151261                0          26 2023-01-14 04:40:10
# 151262                0          22 2023-01-14 04:40:10
# ...                 ...         ...                 ...
# 151300                0          28 2023-01-14 04:43:06
# 151301                0          26 2023-01-14 04:43:06
# 151302                0          27 2023-01-14 04:43:36
# 151303                0          28 2023-01-14 04:43:36
# 151304                0          28 2023-01-14 04:43:36
#
# [47 rows x 16 columns]

# %%
m9[(m9['sc-status'] == 404)]
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 151266  2023-01-14  04:40:25  167.167.244.11       GET  rfoaized.css
# 151272  2023-01-14  04:41:03  167.167.244.11       GET  cwiyhchx.css
# 151286  2023-01-14  04:42:11  167.167.244.11       GET  vsvndsez.css
# 151295  2023-01-14  04:42:55  167.167.244.11       GET  welcidih.css
# 151298  2023-01-14  04:43:06  167.167.244.11       GET  nctohcyq.css
#
#        cs-uri-query  s-port cs-username          c-ip  \
# 151266            -     443           -  78.40.22.101
# 151272            -     443    hg463223  78.40.22.101
# 151286            -     443    hg463223  78.40.22.101
# 151295            -     443    hg463223  78.40.22.101
# 151298            -     443    hg463223  78.40.22.101
#
#                                            cs(User-Agent)  \
# 151266  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151272  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151286  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151295  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151298  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 151266         https://uwetech.co.uk/index.aspx        404             0
# 151272         https://uwetech.co.uk/login.aspx        404             0
# 151286  https://uwetech.co.uk/transactions.aspx        404             0
# 151295  https://uwetech.co.uk/transactions.aspx        404             0
# 151298      https://uwetech.co.uk/transfer.aspx        404             0
#
#         sc-win32-status  time-taken            datetime
# 151266                0          27 2023-01-14 04:40:25
# 151272                0          27 2023-01-14 04:41:03
# 151286                0          24 2023-01-14 04:42:11
# 151295                0          29 2023-01-14 04:42:55
# 151298                0          26 2023-01-14 04:43:06

# %%
m9[(m9['sc-status'] == 200)]
# Out:
#               date      time            s-ip cs-method  \
# 151258  2023-01-14  04:40:00  167.167.244.11       GET
# 151259  2023-01-14  04:40:00  167.167.244.11       GET
# 151260  2023-01-14  04:40:10  167.167.244.11       GET
# 151261  2023-01-14  04:40:10  167.167.244.11       GET
# 151262  2023-01-14  04:40:10  167.167.244.11       GET
# ...            ...       ...             ...       ...
# 151300  2023-01-14  04:43:06  167.167.244.11       GET
# 151301  2023-01-14  04:43:06  167.167.244.11      POST
# 151302  2023-01-14  04:43:36  167.167.244.11       GET
# 151303  2023-01-14  04:43:36  167.167.244.11       GET
# 151304  2023-01-14  04:43:36  167.167.244.11       GET
#
#                    cs-uri-stem      cs-uri-query  s-port cs-username  \
# 151258            grbrijln.css                 -     443           -
# 151259              index.aspx                 -     443           -
# 151260            template.css        v=ggwcnbru     443           -
# 151261            bgumwlja.css                 -     443           -
# 151262              footer.css                 -     443           -
# ...                        ...               ...     ...         ...
# 151300            template.css        v=cibfypuc     443    hg463223
# 151301           transfer.aspx  accountid=668028     443    hg463223
# 151302            template.css        v=zezbvvtm     443    hg463223
# 151303             tjvnmusr.js          v=996105     443    hg463223
# 151304  transfer_complete.aspx                 -     443    hg463223
#
#                 c-ip                                     cs(User-Agent)  \
# 151258  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151259  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151260  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151261  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151262  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# ...              ...                                                ...
# 151300  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151301  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151302  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151303  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 151304  78.40.22.101  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                 cs(Referer)  sc-status  sc-substatus  \
# 151258                                    -        200             0
# 151259                                    -        200             0
# 151260     https://uwetech.co.uk/index.aspx        200             0
# 151261     https://uwetech.co.uk/index.aspx        200             0
# 151262     https://uwetech.co.uk/index.aspx        200             0
# ...                                     ...        ...           ...
# 151300  https://uwetech.co.uk/transfer.aspx        200             0
# 151301  https://uwetech.co.uk/transfer.aspx        200             0
# 151302  https://uwetech.co.uk/transfer.aspx        200             0
# 151303  https://uwetech.co.uk/transfer.aspx        200             0
# 151304  https://uwetech.co.uk/transfer.aspx        200             0
#
#         sc-win32-status  time-taken            datetime
# 151258                0          27 2023-01-14 04:40:00
# 151259                0          24 2023-01-14 04:40:00
# 151260                0          27 2023-01-14 04:40:10
# 151261                0          26 2023-01-14 04:40:10
# 151262                0          22 2023-01-14 04:40:10
# ...                 ...         ...                 ...
# 151300                0          28 2023-01-14 04:43:06
# 151301                0          26 2023-01-14 04:43:06
# 151302                0          27 2023-01-14 04:43:36
# 151303                0          28 2023-01-14 04:43:36
# 151304                0          28 2023-01-14 04:43:36
#
# [40 rows x 16 columns]

# %% [markdown]
# # 2.6 List status `404` in January
# - So far, `2023-01-14` and `2023-01-17` had been investigated.
# - By investigating the number of `404` attempts from `2023-01-01` to `2023-01-30`, the more suspicious high number will be recongnized as suspicious attempts.

# %%
import datetime

# Initialize an empty dictionary
date_dict = {}

# Start date
start_date = datetime.date(2023, 1, 1)

# Iterate over the range from 1 to 31
for i in range(1, 31):
    # Calculate the date for the current iteration
    current_date = start_date + datetime.timedelta(days=i-1)
    if i < 10:
        xx = ab_df[(ab_df['sc-status'] == 404)&(ab_df['date'] == '2023-01-0'+str(i))]
    else:
        xx = ab_df[(ab_df['sc-status'] == 404)&(ab_df['date'] == '2023-01-'+str(i))]
    len_x = len(xx)
    # Add the date and corresponding number to the dictionary
    date_dict[current_date.strftime('%Y-%m-%d')] = len_x

# Print the dictionary
for key, value in date_dict.items():
    print(key, value)
# Out:
# 2023-01-01 23
# 2023-01-02 38
# 2023-01-03 19
# 2023-01-04 23
# 2023-01-05 19
# 2023-01-06 6
# 2023-01-07 20
# 2023-01-08 42
# 2023-01-09 40
# 2023-01-10 21
# 2023-01-11 26
# 2023-01-12 38
# 2023-01-13 23
# 2023-01-14 26
# 2023-01-15 39
# 2023-01-16 22
# 2023-01-17 12
# 2023-01-18 22
# 2023-01-19 32
# 2023-01-20 23
# 2023-01-21 36
# 2023-01-22 28
# 2023-01-23 52
# 2023-01-24 23
# 2023-01-25 36
# 2023-01-26 21
# 2023-01-27 30
# 2023-01-28 29
# 2023-01-29 22
# 2023-01-30 33

# %% [markdown]
# ###  2.6.1 Use lineplot to display daily 404 numbers
# - It seems `2023-01-23`has highest peak of 404 attempts.

# %%
# Convert the dictionary 'date_dict' into a DataFrame
jj = pd.DataFrame(list(date_dict.items()), columns=['Date', 'Value'])

# Set the 'Date' column as datetime type
jj['Date'] = pd.to_datetime(jj['Date'])

# Create line plot using seaborn
plt.figure(figsize=(14, 6))
sns.lineplot(x='Date', y='Value', data=jj, marker='o')
plt.title('Each day 404 status ')
plt.xlabel('Date')
plt.ylabel('Number of records')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# ### 2.6.2 Start Investigate suspicious activities on `2023-01-23`
# - `ab_df` is the filtered data listing activities from 00:00 A.M. to 05:00 A.M.

# %%
d = ab_df[ab_df['date'] == '2023-01-23']
dd = d[(ab_df['sc-status'] == 404)]
dd
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 258223  2023-01-23  00:01:29  167.167.244.11       GET  shdyyccf.css
# 258229  2023-01-23  00:02:10  167.167.244.11       GET  mkxgvxsm.css
# 258239  2023-01-23  00:10:23  167.167.244.11       GET  pubatrol.css
# 258272  2023-01-23  00:25:00  167.167.244.11       GET  tirywcll.css
# 258277  2023-01-23  00:25:41  167.167.244.11       GET  eyehfebc.css
# ...            ...       ...             ...       ...           ...
# 258740  2023-01-23  04:26:28  167.167.244.11       GET  pdqpyyoy.css
# 258745  2023-01-23  04:26:53  167.167.244.11       GET  xvkwpked.css
# 258750  2023-01-23  04:27:07  167.167.244.11       GET  xhetmznq.css
# 258754  2023-01-23  04:27:39  167.167.244.11       GET  smjamhrs.css
# 258758  2023-01-23  04:27:53  167.167.244.11       GET  bozzxutw.css
#
#        cs-uri-query  s-port cs-username             c-ip  \
# 258223            -     443    lx530827    154.15.15.189
# 258229            -     443    lx530827    154.15.15.189
# 258239            -     443           -    57.251.10.205
# 258272            -     443           -   185.22.170.240
# 258277            -     443           -   185.22.170.240
# ...             ...     ...         ...              ...
# 258740            -     443           -  193.104.140.141
# 258745            -     443           -  193.104.140.141
# 258750            -     443    el907176  193.104.140.141
# 258754            -     443    el907176  193.104.140.141
# 258758            -     443           -  193.104.140.141
#
#                                            cs(User-Agent)  \
# 258223  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_4_1+like...
# 258229  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_4_1+like...
# 258239  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_1_4+like...
# 258272  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258277  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# ...                                                   ...
# 258740  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258745  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258750  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258754  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258758  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
#
#                                      cs(Referer)  sc-status  sc-substatus  \
# 258223   https://uwetech.co.uk/transactions.aspx        404             0
# 258229  https://uwetech.co.uk/change_avatar.aspx        404             0
# 258239          https://uwetech.co.uk/index.aspx        404             0
# 258272                                         -        404             0
# 258277          https://uwetech.co.uk/index.aspx        404             0
# ...                                          ...        ...           ...
# 258740          https://uwetech.co.uk/index.aspx        404             0
# 258745          https://uwetech.co.uk/index.aspx        404             0
# 258750          https://uwetech.co.uk/login.aspx        404             0
# 258754   https://uwetech.co.uk/transactions.aspx        404             0
# 258758   https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258223                0          23 2023-01-23 00:01:29  False
# 258229                0          28 2023-01-23 00:02:10  False
# 258239                0          20 2023-01-23 00:10:23  False
# 258272                0          24 2023-01-23 00:25:00  False
# 258277                0          20 2023-01-23 00:25:41  False
# ...                 ...         ...                 ...    ...
# 258740                0          26 2023-01-23 04:26:28  False
# 258745                0          29 2023-01-23 04:26:53  False
# 258750                0          20 2023-01-23 04:27:07  False
# 258754                0          28 2023-01-23 04:27:39  False
# 258758                0          29 2023-01-23 04:27:53  False
#
# [52 rows x 17 columns]

# %% [markdown]
# # 2.7 Suspicious usernames
# - `lj108746` failed 5 times
# - `ti105022` failed 3 times
# - `mo636614` failed 3 times

# %%
dd['cs-username'].value_counts()
# Out:
# cs-username
# -           21
# lj108746     5
# ti105022     3
# mo636614     3
# ou515408     3
# lx530827     2
# pz713951     2
# fb829962     2
# yq720330     2
# ux311934     2
# dy976342     2
# el907176     2
# sz439887     1
# vo286898     1
# yb167630     1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.7.1 List the user `lj108746`'s activities
# - `dd` is the filtered data listing activities from 00:00 A.M. to 05:00 A.M. on `2023-01-23` only.

# %%
m10 = dd[dd['cs-username'] == 'lj108746']
m10
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 258283  2023-01-23  00:25:57  167.167.244.11       GET  eqasnhpr.css
# 258286  2023-01-23  00:26:25  167.167.244.11       GET  mzpkxqbm.css
# 258287  2023-01-23  00:26:25  167.167.244.11       GET  kawozztg.css
# 258298  2023-01-23  00:27:34  167.167.244.11       GET  rgnuezrk.css
# 258302  2023-01-23  00:27:51  167.167.244.11       GET  trlxwoyr.css
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 258283            -     443    lj108746  185.22.170.240
# 258286            -     443    lj108746  185.22.170.240
# 258287            -     443    lj108746  185.22.170.240
# 258298            -     443    lj108746  185.22.170.240
# 258302            -     443    lj108746  185.22.170.240
#
#                                            cs(User-Agent)  \
# 258283  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258286  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258287  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258298  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258302  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 258283         https://uwetech.co.uk/login.aspx        404             0
# 258286         https://uwetech.co.uk/login.aspx        404             0
# 258287         https://uwetech.co.uk/login.aspx        404             0
# 258298  https://uwetech.co.uk/transactions.aspx        404             0
# 258302  https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258283                0          27 2023-01-23 00:25:57  False
# 258286                0          30 2023-01-23 00:26:25  False
# 258287                0          28 2023-01-23 00:26:25  False
# 258298                0          25 2023-01-23 00:27:34  False
# 258302                0          22 2023-01-23 00:27:51  False

# %% [markdown]
# ### 2.7.2 List the user `ti105022`'s activities
# - `dd` is the filtered data listing activities from 00:00 A.M. to 05:00 A.M. on `2023-01-23` only.

# %%
m11 = dd[dd['cs-username'] == 'ti105022']
m11
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 258321  2023-01-23  00:55:28  167.167.244.11       GET  nwzrtgae.css
# 258327  2023-01-23  00:56:01  167.167.244.11       GET  zjttpreo.css
# 258329  2023-01-23  00:56:25  167.167.244.11       GET  jhdfqqnl.css
#
#        cs-uri-query  s-port cs-username           c-ip  \
# 258321            -     443    ti105022  195.212.67.12
# 258327            -     443    ti105022  195.212.67.12
# 258329            -     443    ti105022  195.212.67.12
#
#                                            cs(User-Agent)  \
# 258321  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 258327  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
# 258329  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+13_3+like+M...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 258321           https://uwetech.co.uk/login.aspx        404             0
# 258327  https://uwetech.co.uk/account_status.aspx        404             0
# 258329    https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258321                0          23 2023-01-23 00:55:28  False
# 258327                0          23 2023-01-23 00:56:01  False
# 258329                0          30 2023-01-23 00:56:25  False

# %% [markdown]
# ### 2.7.3 List the user `mo636614`'s activities
# - `dd` is the filtered data listing activities from 00:00 A.M. to 05:00 A.M. on `2023-01-23` only.

# %%
m12 = dd[dd['cs-username'] == 'mo636614']
m12
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 258633  2023-01-23  02:40:11  167.167.244.11       GET  igngvuff.css
# 258634  2023-01-23  02:40:11  167.167.244.11       GET  lbyxxugw.css
# 258648  2023-01-23  02:41:01  167.167.244.11       GET  sgluymvp.css
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 258633            -     443    mo636614  178.73.221.232
# 258634            -     443    mo636614  178.73.221.232
# 258648            -     443    mo636614  178.73.221.232
#
#                                            cs(User-Agent)  \
# 258633  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 258634  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
# 258648  Mozilla/5.0+(Windows+NT+10.0;+Win64;+x64)+Appl...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 258633         https://uwetech.co.uk/login.aspx        404             0
# 258634         https://uwetech.co.uk/login.aspx        404             0
# 258648  https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258633                0          20 2023-01-23 02:40:11  False
# 258634                0          23 2023-01-23 02:40:11  False
# 258648                0          29 2023-01-23 02:41:01  False

# %% [markdown]
# # 2.8 Suspicious `c-ip`s
# - `185.22.170.240` failed 7 times
# - `193.104.140.141` failed 6 times
# - `109.107.35.146` failed 5 times

# %%
dd['c-ip'].value_counts()
# Out:
# c-ip
# 185.22.170.240     7
# 193.104.140.141    6
# 194.154.124.8      5
# 109.107.35.146     4
# 87.248.158.37      4
# 178.73.221.232     4
# 195.212.67.12      3
# 5.252.146.42       3
# 195.242.223.3      3
# 194.69.101.167     3
# 154.15.15.189      2
# 194.33.232.242     2
# 194.221.107.191    2
# 195.212.163.63     2
# 57.251.10.205      1
# 104.78.163.232     1
# Name: count, dtype: int64

# %% [markdown]
# ### Investigate suspicious `c-ip`s
# - Check suspicious activites on `2023-01-23`

# %% [markdown]
# ### 2.8.1 Suspicious c-ip `185.22.170.240`

# %%
m12 = dd[dd['c-ip'] == '185.22.170.240']
m12
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 258272  2023-01-23  00:25:00  167.167.244.11       GET  tirywcll.css
# 258277  2023-01-23  00:25:41  167.167.244.11       GET  eyehfebc.css
# 258283  2023-01-23  00:25:57  167.167.244.11       GET  eqasnhpr.css
# 258286  2023-01-23  00:26:25  167.167.244.11       GET  mzpkxqbm.css
# 258287  2023-01-23  00:26:25  167.167.244.11       GET  kawozztg.css
# 258298  2023-01-23  00:27:34  167.167.244.11       GET  rgnuezrk.css
# 258302  2023-01-23  00:27:51  167.167.244.11       GET  trlxwoyr.css
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 258272            -     443           -  185.22.170.240
# 258277            -     443           -  185.22.170.240
# 258283            -     443    lj108746  185.22.170.240
# 258286            -     443    lj108746  185.22.170.240
# 258287            -     443    lj108746  185.22.170.240
# 258298            -     443    lj108746  185.22.170.240
# 258302            -     443    lj108746  185.22.170.240
#
#                                            cs(User-Agent)  \
# 258272  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258277  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258283  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258286  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258287  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258298  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258302  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 258272                                        -        404             0
# 258277         https://uwetech.co.uk/index.aspx        404             0
# 258283         https://uwetech.co.uk/login.aspx        404             0
# 258286         https://uwetech.co.uk/login.aspx        404             0
# 258287         https://uwetech.co.uk/login.aspx        404             0
# 258298  https://uwetech.co.uk/transactions.aspx        404             0
# 258302  https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258272                0          24 2023-01-23 00:25:00  False
# 258277                0          20 2023-01-23 00:25:41  False
# 258283                0          27 2023-01-23 00:25:57  False
# 258286                0          30 2023-01-23 00:26:25  False
# 258287                0          28 2023-01-23 00:26:25  False
# 258298                0          25 2023-01-23 00:27:34  False
# 258302                0          22 2023-01-23 00:27:51  False

# %% [markdown]
# ### 2.8.2 Suspicious c-ip `193.104.140.141`

# %%
m13 =dd[dd['c-ip'] == '193.104.140.141']
m13
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 258735  2023-01-23  04:26:00  167.167.244.11       GET  udkqfzoy.css
# 258740  2023-01-23  04:26:28  167.167.244.11       GET  pdqpyyoy.css
# 258745  2023-01-23  04:26:53  167.167.244.11       GET  xvkwpked.css
# 258750  2023-01-23  04:27:07  167.167.244.11       GET  xhetmznq.css
# 258754  2023-01-23  04:27:39  167.167.244.11       GET  smjamhrs.css
# 258758  2023-01-23  04:27:53  167.167.244.11       GET  bozzxutw.css
#
#        cs-uri-query  s-port cs-username             c-ip  \
# 258735            -     443           -  193.104.140.141
# 258740            -     443           -  193.104.140.141
# 258745            -     443           -  193.104.140.141
# 258750            -     443    el907176  193.104.140.141
# 258754            -     443    el907176  193.104.140.141
# 258758            -     443           -  193.104.140.141
#
#                                            cs(User-Agent)  \
# 258735  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258740  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258745  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258750  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258754  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258758  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 258735                                        -        404             0
# 258740         https://uwetech.co.uk/index.aspx        404             0
# 258745         https://uwetech.co.uk/index.aspx        404             0
# 258750         https://uwetech.co.uk/login.aspx        404             0
# 258754  https://uwetech.co.uk/transactions.aspx        404             0
# 258758  https://uwetech.co.uk/transactions.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258735                0          24 2023-01-23 04:26:00  False
# 258740                0          26 2023-01-23 04:26:28  False
# 258745                0          29 2023-01-23 04:26:53  False
# 258750                0          20 2023-01-23 04:27:07  False
# 258754                0          28 2023-01-23 04:27:39  False
# 258758                0          29 2023-01-23 04:27:53  False

# %% [markdown]
# ### 2.8.3 Suspicious c-ip `109.107.35.146`

# %%
m14 =dd[dd['c-ip'] == '109.107.35.146']
m14
# Out:
#               date      time            s-ip cs-method   cs-uri-stem  \
# 258495  2023-01-23  01:47:00  167.167.244.11       GET  xqzbtjoc.css
# 258499  2023-01-23  01:47:31  167.167.244.11       GET  uzmnrhqz.css
# 258516  2023-01-23  01:49:50  167.167.244.11       GET  sixyqoir.css
# 258517  2023-01-23  01:49:50  167.167.244.11       GET  craseuft.css
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 258495            -     443    ux311934  109.107.35.146
# 258499            -     443    ux311934  109.107.35.146
# 258516            -     443           -  109.107.35.146
# 258517            -     443           -  109.107.35.146
#
#                                            cs(User-Agent)  \
# 258495  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258499  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258516  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258517  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 258495  https://uwetech.co.uk/account_status.aspx        404             0
# 258499    https://uwetech.co.uk/transactions.aspx        404             0
# 258516  https://uwetech.co.uk/account_status.aspx        404             0
# 258517  https://uwetech.co.uk/account_status.aspx        404             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258495                0          27 2023-01-23 01:47:00  False
# 258499                0          24 2023-01-23 01:47:31  False
# 258516                0          30 2023-01-23 01:49:50  False
# 258517                0          21 2023-01-23 01:49:50  False

# %% [markdown]
# # 2.9 List suspicious user's activites with status `200`
# - `d` is the data listing all activities on `2023-01-23` from 00:00 A.M. to 05:00 A.M (including 200 & 404).
# - Compare the activities with status `200` with those with `404`.

# %%
d_200 = d[d['sc-status'] == 200]
d_200.head()
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 258210  2023-01-23  00:00:12  167.167.244.11       GET       jjowcudq.css
# 258211  2023-01-23  00:00:12  167.167.244.11       GET       cpvqghpv.css
# 258212  2023-01-23  00:00:12  167.167.244.11       GET  transactions.aspx
# 258213  2023-01-23  00:00:38  167.167.244.11       GET         footer.css
# 258214  2023-01-23  00:00:38  167.167.244.11       GET  transactions.aspx
#
#        cs-uri-query  s-port cs-username           c-ip  \
# 258210            -     443    lx530827  154.15.15.189
# 258211            -     443    lx530827  154.15.15.189
# 258212       page=2     443    lx530827  154.15.15.189
# 258213            -     443    lx530827  154.15.15.189
# 258214       page=1     443    lx530827  154.15.15.189
#
#                                            cs(User-Agent)  \
# 258210  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_4_1+like...
# 258211  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_4_1+like...
# 258212  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_4_1+like...
# 258213  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_4_1+like...
# 258214  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+12_4_1+like...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 258210  https://uwetech.co.uk/account_status.aspx        200             0
# 258211  https://uwetech.co.uk/account_status.aspx        200             0
# 258212  https://uwetech.co.uk/account_status.aspx        200             0
# 258213    https://uwetech.co.uk/transactions.aspx        200             0
# 258214    https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258210                0          27 2023-01-23 00:00:12  False
# 258211                0          20 2023-01-23 00:00:12  False
# 258212                0          24 2023-01-23 00:00:12  False
# 258213                0          29 2023-01-23 00:00:38  False
# 258214                0          25 2023-01-23 00:00:38  False

# %% [markdown]
# ### 2.9.1 List suspicious c-ip `185.22.170.240`'s activites with status 200

# %%
m15 = d_200[d_200['c-ip'] == '185.22.170.240']
m15
# Out:
#               date      time            s-ip cs-method        cs-uri-stem  \
# 258273  2023-01-23  00:25:00  167.167.244.11       GET       template.css
# 258274  2023-01-23  00:25:00  167.167.244.11       GET         index.aspx
# 258275  2023-01-23  00:25:26  167.167.244.11       GET        cogbrwbk.js
# 258276  2023-01-23  00:25:26  167.167.244.11       GET         index.aspx
# 258278  2023-01-23  00:25:41  167.167.244.11       GET       template.css
# ...            ...       ...             ...       ...                ...
# 258306  2023-01-23  00:28:01  167.167.244.11       GET        zhwjumgw.js
# 258307  2023-01-23  00:28:01  167.167.244.11       GET  transactions.aspx
# 258308  2023-01-23  00:28:30  167.167.244.11       GET       ifseaexe.css
# 258309  2023-01-23  00:28:30  167.167.244.11       GET         footer.css
# 258310  2023-01-23  00:28:30  167.167.244.11       GET  transactions.aspx
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 258273   v=obnurqxt     443           -  185.22.170.240
# 258274            -     443           -  185.22.170.240
# 258275     v=202264     443           -  185.22.170.240
# 258276            -     443           -  185.22.170.240
# 258278   v=ivsgffli     443           -  185.22.170.240
# ...             ...     ...         ...             ...
# 258306     v=832149     443    lj108746  185.22.170.240
# 258307       page=5     443    lj108746  185.22.170.240
# 258308            -     443    lj108746  185.22.170.240
# 258309            -     443    lj108746  185.22.170.240
# 258310       page=6     443    lj108746  185.22.170.240
#
#                                            cs(User-Agent)  \
# 258273  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258274  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258275  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258276  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258278  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# ...                                                   ...
# 258306  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258307  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258308  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258309  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
# 258310  Mozilla/4.0+(compatible;+MSIE+6.0;+Windows+NT+...
#
#                                     cs(Referer)  sc-status  sc-substatus  \
# 258273                                        -        200             0
# 258274                                        -        200             0
# 258275         https://uwetech.co.uk/index.aspx        200             0
# 258276         https://uwetech.co.uk/index.aspx        200             0
# 258278         https://uwetech.co.uk/index.aspx        200             0
# ...                                         ...        ...           ...
# 258306  https://uwetech.co.uk/transactions.aspx        200             0
# 258307  https://uwetech.co.uk/transactions.aspx        200             0
# 258308  https://uwetech.co.uk/transactions.aspx        200             0
# 258309  https://uwetech.co.uk/transactions.aspx        200             0
# 258310  https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258273                0          25 2023-01-23 00:25:00   True
# 258274                0          21 2023-01-23 00:25:00  False
# 258275                0          28 2023-01-23 00:25:26   True
# 258276                0          29 2023-01-23 00:25:26  False
# 258278                0          29 2023-01-23 00:25:41   True
# ...                 ...         ...                 ...    ...
# 258306                0          25 2023-01-23 00:28:01   True
# 258307                0          27 2023-01-23 00:28:01  False
# 258308                0          30 2023-01-23 00:28:30  False
# 258309                0          26 2023-01-23 00:28:30  False
# 258310                0          20 2023-01-23 00:28:30  False
#
# [30 rows x 17 columns]

# %% [markdown]
# ### 2.9.2 List suspicious c-ip `193.104.140.141`'s activites with status 200

# %%
m16 = d_200[d_200['c-ip'] == '193.104.140.141']
m16
# Out:
#               date      time            s-ip cs-method          cs-uri-stem  \
# 258734  2023-01-23  04:26:00  167.167.244.11       GET           footer.css
# 258736  2023-01-23  04:26:00  167.167.244.11       GET             main.css
# 258737  2023-01-23  04:26:00  167.167.244.11       GET           index.aspx
# 258738  2023-01-23  04:26:04  167.167.244.11       GET           footer.css
# 258739  2023-01-23  04:26:04  167.167.244.11       GET           index.aspx
# 258741  2023-01-23  04:26:28  167.167.244.11       GET         template.css
# 258742  2023-01-23  04:26:28  167.167.244.11       GET         template.css
# 258744  2023-01-23  04:26:53  167.167.244.11       GET             main.css
# 258746  2023-01-23  04:26:53  167.167.244.11       GET           login.aspx
# 258747  2023-01-23  04:26:57  167.167.244.11       GET         eldixuyy.css
# 258749  2023-01-23  04:27:07  167.167.244.11       GET             main.css
# 258751  2023-01-23  04:27:07  167.167.244.11       GET  account_status.aspx
# 258752  2023-01-23  04:27:33  167.167.244.11       GET          sbykxuui.js
# 258753  2023-01-23  04:27:33  167.167.244.11       GET    transactions.aspx
# 258755  2023-01-23  04:27:39  167.167.244.11       GET           footer.css
# 258756  2023-01-23  04:27:39  167.167.244.11       GET          phdsefqf.js
# 258757  2023-01-23  04:27:39  167.167.244.11       GET    transactions.aspx
#
#        cs-uri-query  s-port cs-username             c-ip  \
# 258734            -     443           -  193.104.140.141
# 258736            -     443           -  193.104.140.141
# 258737            -     443           -  193.104.140.141
# 258738            -     443           -  193.104.140.141
# 258739            -     443           -  193.104.140.141
# 258741   v=dilezycx     443           -  193.104.140.141
# 258742   v=ubbdbiwx     443           -  193.104.140.141
# 258744            -     443           -  193.104.140.141
# 258746            -     443           -  193.104.140.141
# 258747            -     443    el907176  193.104.140.141
# 258749            -     443    el907176  193.104.140.141
# 258751            -     443    el907176  193.104.140.141
# 258752     v=534643     443    el907176  193.104.140.141
# 258753       page=2     443    el907176  193.104.140.141
# 258755            -     443    el907176  193.104.140.141
# 258756     v=766536     443    el907176  193.104.140.141
# 258757       page=1     443    el907176  193.104.140.141
#
#                                            cs(User-Agent)  \
# 258734  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258736  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258737  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258738  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258739  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258741  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258742  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258744  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258746  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258747  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258749  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258751  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258752  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258753  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258755  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258756  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
# 258757  Mozilla/5.0+(iPhone;+CPU+iPhone+OS+10_3_2+like...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 258734                                          -        200             0
# 258736                                          -        200             0
# 258737                                          -        200             0
# 258738           https://uwetech.co.uk/index.aspx        200             0
# 258739           https://uwetech.co.uk/index.aspx        200             0
# 258741           https://uwetech.co.uk/index.aspx        200             0
# 258742           https://uwetech.co.uk/index.aspx        200             0
# 258744           https://uwetech.co.uk/index.aspx        200             0
# 258746           https://uwetech.co.uk/index.aspx        200             0
# 258747           https://uwetech.co.uk/login.aspx        200             0
# 258749           https://uwetech.co.uk/login.aspx        200             0
# 258751           https://uwetech.co.uk/login.aspx        200             0
# 258752  https://uwetech.co.uk/account_status.aspx        200             0
# 258753  https://uwetech.co.uk/account_status.aspx        200             0
# 258755    https://uwetech.co.uk/transactions.aspx        200             0
# 258756    https://uwetech.co.uk/transactions.aspx        200             0
# 258757    https://uwetech.co.uk/transactions.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258734                0          25 2023-01-23 04:26:00  False
# 258736                0          21 2023-01-23 04:26:00  False
# 258737                0          25 2023-01-23 04:26:00  False
# 258738                0          25 2023-01-23 04:26:04  False
# 258739                0          29 2023-01-23 04:26:04  False
# 258741                0          29 2023-01-23 04:26:28   True
# 258742                0          25 2023-01-23 04:26:28   True
# 258744                0          27 2023-01-23 04:26:53  False
# 258746                0          22 2023-01-23 04:26:53  False
# 258747                0          28 2023-01-23 04:26:57  False
# 258749                0          27 2023-01-23 04:27:07  False
# 258751                0          25 2023-01-23 04:27:07  False
# 258752                0          20 2023-01-23 04:27:33   True
# 258753                0          22 2023-01-23 04:27:33  False
# 258755                0          25 2023-01-23 04:27:39  False
# 258756                0          27 2023-01-23 04:27:39   True
# 258757                0          20 2023-01-23 04:27:39  False

# %% [markdown]
# ### 2.9.3 List suspicious c-ip `109.107.35.146`'s activites with status 200

# %%
m17= d_200[d_200['c-ip'] == '109.107.35.146']
m17
# Out:
#               date      time            s-ip cs-method          cs-uri-stem  \
# 258474  2023-01-23  01:45:00  167.167.244.11       GET          bpjhndkp.js
# 258475  2023-01-23  01:45:00  167.167.244.11       GET           index.aspx
# 258481  2023-01-23  01:45:21  167.167.244.11       GET         imsowxez.css
# 258482  2023-01-23  01:45:21  167.167.244.11       GET           favico.ico
# 258483  2023-01-23  01:45:21  167.167.244.11       GET           index.aspx
# ...            ...       ...             ...       ...                  ...
# 258510  2023-01-23  01:49:19  167.167.244.11       GET           favico.ico
# 258512  2023-01-23  01:49:45  167.167.244.11       GET           favico.ico
# 258513  2023-01-23  01:49:45  167.167.244.11       GET           favico.ico
# 258514  2023-01-23  01:49:45  167.167.244.11       GET  account_status.aspx
# 258515  2023-01-23  01:49:50  167.167.244.11       GET         hfljhuug.css
#
#        cs-uri-query  s-port cs-username            c-ip  \
# 258474     v=698388     443           -  109.107.35.146
# 258475            -     443           -  109.107.35.146
# 258481            -     443           -  109.107.35.146
# 258482            -     443           -  109.107.35.146
# 258483            -     443           -  109.107.35.146
# ...             ...     ...         ...             ...
# 258510            -     443    ux311934  109.107.35.146
# 258512            -     443    ux311934  109.107.35.146
# 258513            -     443    ux311934  109.107.35.146
# 258514            -     443    ux311934  109.107.35.146
# 258515            -     443           -  109.107.35.146
#
#                                            cs(User-Agent)  \
# 258474  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258475  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258481  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258482  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258483  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# ...                                                   ...
# 258510  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258512  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258513  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258514  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
# 258515  Mozilla/5.0+(Windows+NT+6.1;+Win64;+x64)+Apple...
#
#                                       cs(Referer)  sc-status  sc-substatus  \
# 258474                                          -        200             0
# 258475                                          -        200             0
# 258481           https://uwetech.co.uk/index.aspx        200             0
# 258482           https://uwetech.co.uk/index.aspx        200             0
# 258483           https://uwetech.co.uk/index.aspx        200             0
# ...                                           ...        ...           ...
# 258510  https://uwetech.co.uk/changepassword.aspx        200             0
# 258512  https://uwetech.co.uk/changepassword.aspx        200             0
# 258513  https://uwetech.co.uk/changepassword.aspx        200             0
# 258514  https://uwetech.co.uk/changepassword.aspx        200             0
# 258515  https://uwetech.co.uk/account_status.aspx        200             0
#
#         sc-win32-status  time-taken            datetime    cuq
# 258474                0          26 2023-01-23 01:45:00   True
# 258475                0          20 2023-01-23 01:45:00  False
# 258481                0          22 2023-01-23 01:45:21  False
# 258482                0          20 2023-01-23 01:45:21  False
# 258483                0          21 2023-01-23 01:45:21  False
# ...                 ...         ...                 ...    ...
# 258510                0          26 2023-01-23 01:49:19  False
# 258512                0          22 2023-01-23 01:49:45  False
# 258513                0          20 2023-01-23 01:49:45  False
# 258514                0          26 2023-01-23 01:49:45  False
# 258515                0          24 2023-01-23 01:49:50  False
#
# [32 rows x 17 columns]

# %% [markdown]
# # 3 Clarity and presentation

# %% [markdown]
# ## 3.1 Clarity of the date for suspicious activities
# ### `2023-01-14`
# - 3 users were suspicious.
# - `2.22.140.181` (up356345)
#     - There were 38 activities.
#     - `404`: 8 attempts at midnight then succeeded for login & transaction (02:49:12 - 02:52:07).
#     - `200`: 30 attempts succeeded at midnight (02:49:00 - 02:52:07).
#
# - `78.40.22.101` (hg463223)
#     - `404`: 4 failed attempts at midnight then succeeded for login & transaction.
#     - `202`: 29 attempts succeeded at midnight.
#
# ### `2023-01-16`
# - 2 users were suspicious by referring to the same uri-query `v=843338`.
# - `207.54.88.2` (vw112707)
#     - There were 2 suspicious attempts on 2023-01-16 at midnight from 01:29:24 A.M. to 01:31:10 A.M.
# - `31.3.244.34` (yb371329)
# - `v=843338`: 2023-01-16(207.54.88.2) & 2023-01-22(31.3.244.34).
#
#
#
# ### `2023-01-17`
# - This date has the highest data but the lowest `404` status, as shown in *Figure 1 & Figure 2*.
# - **Benign**.
#
# ### `2023-01-23`
# - This date has normal amount of daily data transit, however, the highest amount of status `404` attempts.
# - **Suspicious**.
# - `185.22.170.240` (lj108746)
#     - `404`: 7 attempts at midnight then succeeded for login & transaction(00:25:00 - 00:27:51).
#     - `200`: 30 attempts succeeded at midnight.
# - `193.104.140.141` (el907176)
#     - `404`: 6 attempts at midnight then succeeded for login & transaction(04:26:00- 04:27:53).
#     - `200`: 17 attempts succeeded at midnight (04:26:00 - 04:27:39).

# %% [markdown]
# # Figure 1

# %%
# Create line plot using seaborn
plt.figure(figsize=(14, 6))
sns.set_theme(style="darkgrid")

# sns.lineplot(x='Date', y='Value', data=jj, marker='o')
sns.lineplot(x='Date', y='Value', data=dff, marker='v', markersize=13)


plt.title('Daily data')
plt.xlabel('Date')
plt.ylabel('Number of records')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# # Figure 2

# %%
# Create line plot using seaborn
plt.figure(figsize=(14, 6))
sns.set_theme(style="darkgrid", palette="Spectral")
sns.lineplot(x='Date', y='Value', data=jj, marker='o', markersize=8)
# sns.lineplot(x='Date', y='Value', data=dff, marker='o')

plt.title('Daily 404')
plt.xlabel('Date')
plt.ylabel('Number of records')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
